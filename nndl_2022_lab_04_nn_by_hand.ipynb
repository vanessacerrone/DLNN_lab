# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2022/23 (6 CFU) - Dr. Jacopo Pegoraro, Dr. Daniele Mari
# ---
#
#
# ## Supplementary  material - Neural network manual implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns 

sns.set_style('white')
mpl.rc('xtick.minor', visible = True)
mpl.rc('ytick.minor', visible = True)
mpl.rc('xtick', direction='in', top=True, bottom = True)
mpl.rc('ytick', direction='in', right=True, left = True)
#sns.color_palette("pastel")
# manual implementation: no torch required!
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# # Theoretical Background

# %% [markdown]
# ### Artificial Neuron

# %% [markdown]
# This is the structure of a single artificial neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Fully connected feed-forward network

# %% [markdown]
# A neural network is composed by several artificial neurons, typically organized in layers and connected in different ways. One of the most common neural network is the **fully-connected feed-forward network**, where each neuron is connected to all the neurons of the previous layer. The first layer takes the feature vector as input, and the number of outputs is defined by the number of neurons in the last layer.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# All the linear computation of a single layer (without considering the activation function) can be simply expressed in a matrix form, as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When we include the activation function and we consider more than one layer (2 hidden layers in this example) we still have a quite simple expression for the entire network. $X$ is the input vector, $H_n$ are the linear activations, $Z_n$ are the non-linear activations, and $Y$ is the output.
#
# The computation of this equation is typically referred to as *forward-pass*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# When we use a neural network for a regression or classification problem, we compare the output the network with the actual values given by a training set.
#
# This comparison is quantified by a **loss function**. In this case we consider a Mean Square Error (MSE) function, analogously to the least square problem analyzed in the previous lab.
#
# The main goal is to find a set of parameters $W$ that minimizes the loss function. The rationale behind the **gradient descent** algorithm is to slighlty update the values of the weights depending on their gradient wrt the loss function. The update is repeated until we reach a stopping criteria, e.g. the training loss is not decreasing anymore, or the loss function evaluated on the validation set (**validation loss**) starts to increase (**overfitting**).
#
# It is clear that the main point here is to evaluate the gradient of the weights wrt the loss function. Starting from the output layer, and thanks to the **chain rule**, we can easily leverage previously evaluated gradients to simplify the computation (**back-propagation**).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you apply the chain rule, as you cas see below, most of the computation is shared among the layers.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Doing the math, you have the following gradients. We define the variables $D_n$ to have a reference for the code below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Activation Functions

# %% [markdown]
# There are several non-linear activation function that can be used, each of which has specific properties and tackles specific issues. Here some examples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Generate training and test data

# %% [markdown]
# Let's define the same model used for the OLS implementation of the previous labs.

# %%
# Set random seed
np.random.seed(3)

### Define a simple quadratic model
# y = a + b * x + c * x^2
# a = -1.45, b = 1.12, c = 2.3

def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise
    
### True parameter values
beta_true = [-1.45, 1.12, 2.3]

### Set random seed
np.random.seed(3)

### Generate 10 train points
num_train_points = 10
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std=0.2)

### Generate 10 test points
num_test_points = 10
x_test = np.random.rand(num_test_points)
y_test = poly_model(x_test, beta_true, noise_std=0.2)

### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_test, y_test, color='g', ls='', marker='.', label='Test data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Activation function

# %% [markdown]
# Let's define the activation function *act* and its dervivative *act_der*. We consider a **sigmoid** activation function, which is available in the *scipy* python package in the *scipy.special* module named as *expit*.
#
# Fortunately, the derivative of the sigmoid $\sigma(x)$ is quite simple:
#
# $$
# \sigma(x) = \frac{1}{1+e^{-x}}\\
# \frac{d\sigma}{dx} = \sigma(x) * (1 - \sigma(x))
# $$

# %%
# Define activation function
from scipy.special import expit
##################################
#PUT YOUR CODE HERE
act = expit
# 1st derivative
act_der = lambda x: expit(x)*(1-expit(x))
##################################

# Plot activation function
x_plot = np.linspace(-5,5,1000)
y_act = act(x_plot)
y_act_der = act_der(x_plot)

plt.figure(figsize=(16,10))
plt.plot(x_plot, y_act, label='Sigmoid function')
plt.plot(x_plot, y_act_der, label='Sigmoid 1st derivative')
plt.legend(frameon=False,)
plt.grid()
plt.show()

# %% [markdown]
# # Network definition

# %% [markdown]
# Let's define the entire network using a class. We are implementing a fully connected feed-forward network with 2 hidden layers. The class has the following structure:
# ```
# class Network():
#
#     def __init__(self, Ni, Nh1, Nh2, No):
#         [...]
#
#     def forward(self, x, additional_out=False):
#         [...]
#
#     def update(self, x, label, lr):
#         [...]
#
#     def plot_weights(self):
#         [...]
#
# ```
#
#
# *   **\_\_init\_\_ method** - Here we initialize all the parameters (weights and biases) of the network. It requires the number of inputs ($N_i$) and outputs ($N_o$) and the number of neurons in the hidden layers ($N_h1$ and $N_h2$). The weights are initialized randomly, following the procedure proposed by Xavier et al. i.e. they are initialized with uniform distribution from $$\mathcal{U}(-0.5, 0.5)*\sqrt{\frac{12}{N_i + N_o}}$$
#  The biases are initialized to zero.
# *   **forward** - Evaluate the output of the network given an input $x$. If the *additional_out* parameter is True, it also outputs the activations of the secon hidden layer $Z_2$, for visualization.
# * **update** - Given a training sample (*x* and *label*), evaluate all the gradients and perform the update of the weigths with a learning rate *lr*.
# * **plot_weights** - Utility function to plot all the weights of the network.

# %%
import numpy as np

# %%
class Network():
    
    def __init__(self, Ni, Nh1, Nh2, No):
            
        ### WEIGHT INITIALIZATION (Xavier)
        # Initialize hidden weights and biases (layer 1)
        Wh1 = (np.random.rand(Nh1, Ni) - 0.5) * np.sqrt(12 / (Nh1 + Ni))
        Bh1 = np.zeros([Nh1, 1])
        self.WBh1 = np.concatenate([Wh1, Bh1], 1) # Weight matrix including biases
        # Initialize hidden weights and biases (layer 2)
        Wh2 = (np.random.rand(Nh2, Nh1) - 0.5) * np.sqrt(12 / (Nh2 + Nh1))
        Bh2 = np.zeros([Nh2, 1])
        self.WBh2 = np.concatenate([Wh2, Bh2], 1) # Weight matrix including biases
        # Initialize output weights and biases
        Wo = (np.random.rand(No, Nh2) - 0.5) * np.sqrt(12/(Nh2+No))
        Bo = np.zeros([No, 1])
        self.WBo = np.concatenate([Wo, Bo], 1) # Weight matrix including biases
        
        ### ACTIVATION FUNCTION
        self.act = expit
        self.act_der = lambda x: act(x) * (1 - act(x))
        
    def forward(self, x, additional_out=False):
        
        # Convert to numpy array
        x = np.array(x)
        
        ### Hidden layer 1
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        X = np.append(x, 1)
        # Forward pass (linear)
        H1 = np.matmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)
        
        ### Hidden layer 2
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = np.matmul(self.WBh2, Z1)
        # Activation function
        Z2 = self.act(H2)
        
        ### Output layer
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = np.matmul(self.WBo, Z2)
        # NO activation function
        
        if additional_out:
            return Y.squeeze(), Z2
        
        return Y.squeeze()
        
    def update(self, x, label, lr):
        
        # Convert to numpy array
        X = np.array(x)
        
        ### Hidden layer 1
        # Add bias term
        X = np.append(X, 1)
        # Forward pass (linear)
        H1 = np.matmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)
        
        ### Hidden layer 2
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = np.matmul(self.WBh2, Z1)
        # Activation function
        Z2 = self.act(H2)
        
         ### Output layer
        # Add bias term
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = np.matmul(self.WBo, Z2)
        # NO activation function
        
        # Evaluate the derivative terms
        D1 = Y - label
        D2 = Z2
        D3 = self.WBo[:,:-1]
        D4 = self.act_der(H2)
        D5 = Z1
        D6 = self.WBh2[:,:-1]
        D7 = self.act_der(H1)
        D8 = X
        
        # Layer Error
        Eo = D1
        Eh2 = np.matmul(Eo, D3) * D4
        Eh1 = np.matmul(Eh2, D6) * D7
        
        
        # Derivative for weight matrices
        dWBo = np.matmul(Eo.reshape(-1,1), D2.reshape(1,-1))
        dWBh2 = np.matmul(Eh2.reshape(-1,1), D5.reshape(1,-1))
        dWBh1 = np.matmul(Eh1.reshape(-1,1), D8.reshape(1,-1))
        
        # Update the weights
        self.WBh1 -= lr * dWBh1
        self.WBh2 -= lr * dWBh2
        self.WBo -= lr * dWBo
        
        # Evaluate loss function
        loss = (Y - label)**2/2
        
        return loss
    
    def plot_weights(self):
    
        fig, axs = plt.subplots(3, 1, figsize=(12,6))
        axs[0].hist(self.WBh1.flatten(), 20)
        axs[1].hist(self.WBh2.flatten(), 50)
        axs[2].hist(self.WBo.flatten(), 20)
        plt.legend()
        plt.grid()
        plt.show()

# %% [markdown]
# Now we can instantiate the actual object.

# %%
### PARAMETERS
Ni = 1 # Number of inputs
Nh1 = 128 # Number of hidden neurons (layer 1)
Nh2 = 512 # Number of hidden neurons (layer 2)
No = 1 # Number of outputs

### Initialize network
net = Network(Ni, Nh1, Nh2, No)

# Access the class members
print('1st hidden layer weigth matrix shape:', net.WBh1.shape)
print('2nd hidden layer weigth matrix shape:', net.WBh2.shape)
print('Output layer weigth matrix shape:', net.WBo.shape)

# Plot weights
plt.close('all')
net.plot_weights()
# Out:
# 1st hidden layer weigth matrix shape: (128, 2)
# 2nd hidden layer weigth matrix shape: (512, 129)
# Output layer weigth matrix shape: (1, 513)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Let's check what is the output of the network just initialized, without having performed any training step.

# %%
### FORWARD PASS (before training)
# Define the x vector
x_highres = np.linspace(0, 1, 1000)

# Evaluate the output for each input (this can be done as a batch, but for now let's do 1 input at a time)
initial_net_output = []
for x in x_highres:
    net_out = net.forward(x)
    initial_net_output.append(net_out)
initial_net_output = np.array(initial_net_output)
    
# Or in just 1 line of pythonic code!!
initial_net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, initial_net_output, color='g', ls='--', label='Network output (random weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the output is just a random value. Let's train this network.

# %% [markdown]
# # Network training

# %% [markdown]
# Here, a **learning rate decay** can be optionally enabled, which decrease the learning rate from *lr* to *lr_final* during the training.

# %%
#%% TRAINING
num_epochs = 5000
lr = 1e-2
en_decay = False
lr_final = 1e-5
lr_decay = (lr_final / lr)**(1 / num_epochs)

train_loss_log = []
test_loss_log = []
for num_ep in range(num_epochs):
    # Learning rate decay
    if en_decay:
        lr *= lr_decay
    # Train single epoch (sample by sample, no batch for now)
    train_loss_vec = [net.update(x, y, lr) for x, y in zip(x_train, y_train)]
    avg_train_loss = np.mean(train_loss_vec)
    # Test network
    y_test_est = np.array([net.forward(x) for x in x_test])
    avg_test_loss = np.mean((y_test_est - y_test)**2/2)
    # Log
    train_loss_log.append(avg_train_loss)
    test_loss_log.append(avg_test_loss)
    print('Epoch %d - lr: %.5f - Train loss: %.5f - Test loss: %.5f' % (num_ep + 1, lr, avg_train_loss, avg_test_loss))
# Out:
# Epoch 1 - lr: 0.01000 - Train loss: 0.97084 - Test loss: 0.40051
# Epoch 2 - lr: 0.01000 - Train loss: 0.91191 - Test loss: 0.40150
# Epoch 3 - lr: 0.01000 - Train loss: 0.90933 - Test loss: 0.40250
# Epoch 4 - lr: 0.01000 - Train loss: 0.90685 - Test loss: 0.40352
# Epoch 5 - lr: 0.01000 - Train loss: 0.90446 - Test loss: 0.40456
# Epoch 6 - lr: 0.01000 - Train loss: 0.90216 - Test loss: 0.40560
# Epoch 7 - lr: 0.01000 - Train loss: 0.89993 - Test loss: 0.40665
# Epoch 8 - lr: 0.01000 - Train loss: 0.89779 - Test loss: 0.40771
# Epoch 9 - lr: 0.01000 - Train loss: 0.89572 - Test loss: 0.40878
# Epoch 10 - lr: 0.01000 - Train loss: 0.89373 - Test loss: 0.40985
# Epoch 11 - lr: 0.01000 - Train loss: 0.89180 - Test loss: 0.41093
# Epoch 12 - lr: 0.01000 - Train loss: 0.88994 - Test loss: 0.41202
# Epoch 13 - lr: 0.01000 - Train loss: 0.88815 - Test loss: 0.41310
# Epoch 14 - lr: 0.01000 - Train loss: 0.88642 - Test loss: 0.41419
# Epoch 15 - lr: 0.01000 - Train loss: 0.88474 - Test loss: 0.41529
# Epoch 16 - lr: 0.01000 - Train loss: 0.88312 - Test loss: 0.41638
# Epoch 17 - lr: 0.01000 - Train loss: 0.88156 - Test loss: 0.41748
# Epoch 18 - lr: 0.01000 - Train loss: 0.88004 - Test loss: 0.41858
# Epoch 19 - lr: 0.01000 - Train loss: 0.87858 - Test loss: 0.41968
# Epoch 20 - lr: 0.01000 - Train loss: 0.87716 - Test loss: 0.42077
# Epoch 21 - lr: 0.01000 - Train loss: 0.87580 - Test loss: 0.42187
# Epoch 22 - lr: 0.01000 - Train loss: 0.87447 - Test loss: 0.42297
# Epoch 23 - lr: 0.01000 - Train loss: 0.87319 - Test loss: 0.42407
# Epoch 24 - lr: 0.01000 - Train loss: 0.87195 - Test loss: 0.42516
# Epoch 25 - lr: 0.01000 - Train loss: 0.87074 - Test loss: 0.42626
# Epoch 26 - lr: 0.01000 - Train loss: 0.86958 - Test loss: 0.42735
# Epoch 27 - lr: 0.01000 - Train loss: 0.86845 - Test loss: 0.42844
# Epoch 28 - lr: 0.01000 - Train loss: 0.86736 - Test loss: 0.42953
# Epoch 29 - lr: 0.01000 - Train loss: 0.86630 - Test loss: 0.43062
# Epoch 30 - lr: 0.01000 - Train loss: 0.86528 - Test loss: 0.43170
# Epoch 31 - lr: 0.01000 - Train loss: 0.86428 - Test loss: 0.43278
# Epoch 32 - lr: 0.01000 - Train loss: 0.86332 - Test loss: 0.43386
# Epoch 33 - lr: 0.01000 - Train loss: 0.86238 - Test loss: 0.43494
# Epoch 34 - lr: 0.01000 - Train loss: 0.86148 - Test loss: 0.43602
# Epoch 35 - lr: 0.01000 - Train loss: 0.86060 - Test loss: 0.43709
# Epoch 36 - lr: 0.01000 - Train loss: 0.85974 - Test loss: 0.43816
# Epoch 37 - lr: 0.01000 - Train loss: 0.85891 - Test loss: 0.43923
# Epoch 38 - lr: 0.01000 - Train loss: 0.85811 - Test loss: 0.44029
# Epoch 39 - lr: 0.01000 - Train loss: 0.85733 - Test loss: 0.44136
# Epoch 40 - lr: 0.01000 - Train loss: 0.85657 - Test loss: 0.44242
# Epoch 41 - lr: 0.01000 - Train loss: 0.85583 - Test loss: 0.44348
# Epoch 42 - lr: 0.01000 - Train loss: 0.85512 - Test loss: 0.44453
# Epoch 43 - lr: 0.01000 - Train loss: 0.85442 - Test loss: 0.44558
# Epoch 44 - lr: 0.01000 - Train loss: 0.85375 - Test loss: 0.44664
# Epoch 45 - lr: 0.01000 - Train loss: 0.85309 - Test loss: 0.44768
# Epoch 46 - lr: 0.01000 - Train loss: 0.85246 - Test loss: 0.44873
# Epoch 47 - lr: 0.01000 - Train loss: 0.85183 - Test loss: 0.44977
# Epoch 48 - lr: 0.01000 - Train loss: 0.85123 - Test loss: 0.45081
# Epoch 49 - lr: 0.01000 - Train loss: 0.85064 - Test loss: 0.45185
# Epoch 50 - lr: 0.01000 - Train loss: 0.85007 - Test loss: 0.45289
# Epoch 51 - lr: 0.01000 - Train loss: 0.84952 - Test loss: 0.45392
# Epoch 52 - lr: 0.01000 - Train loss: 0.84898 - Test loss: 0.45495
# Epoch 53 - lr: 0.01000 - Train loss: 0.84845 - Test loss: 0.45598
# Epoch 54 - lr: 0.01000 - Train loss: 0.84794 - Test loss: 0.45701
# Epoch 55 - lr: 0.01000 - Train loss: 0.84744 - Test loss: 0.45803
# Epoch 56 - lr: 0.01000 - Train loss: 0.84695 - Test loss: 0.45905
# Epoch 57 - lr: 0.01000 - Train loss: 0.84648 - Test loss: 0.46008
# Epoch 58 - lr: 0.01000 - Train loss: 0.84601 - Test loss: 0.46109
# Epoch 59 - lr: 0.01000 - Train loss: 0.84556 - Test loss: 0.46211
# Epoch 60 - lr: 0.01000 - Train loss: 0.84512 - Test loss: 0.46312
# Epoch 61 - lr: 0.01000 - Train loss: 0.84469 - Test loss: 0.46414
# Epoch 62 - lr: 0.01000 - Train loss: 0.84427 - Test loss: 0.46515
# Epoch 63 - lr: 0.01000 - Train loss: 0.84387 - Test loss: 0.46615
# Epoch 64 - lr: 0.01000 - Train loss: 0.84347 - Test loss: 0.46716
# Epoch 65 - lr: 0.01000 - Train loss: 0.84308 - Test loss: 0.46816
# Epoch 66 - lr: 0.01000 - Train loss: 0.84270 - Test loss: 0.46917
# Epoch 67 - lr: 0.01000 - Train loss: 0.84233 - Test loss: 0.47017
# Epoch 68 - lr: 0.01000 - Train loss: 0.84196 - Test loss: 0.47116
# Epoch 69 - lr: 0.01000 - Train loss: 0.84161 - Test loss: 0.47216
# Epoch 70 - lr: 0.01000 - Train loss: 0.84126 - Test loss: 0.47316
# Epoch 71 - lr: 0.01000 - Train loss: 0.84092 - Test loss: 0.47415
# Epoch 72 - lr: 0.01000 - Train loss: 0.84059 - Test loss: 0.47514
# Epoch 73 - lr: 0.01000 - Train loss: 0.84026 - Test loss: 0.47613
# Epoch 74 - lr: 0.01000 - Train loss: 0.83994 - Test loss: 0.47711
# Epoch 75 - lr: 0.01000 - Train loss: 0.83963 - Test loss: 0.47810
# Epoch 76 - lr: 0.01000 - Train loss: 0.83932 - Test loss: 0.47908
# Epoch 77 - lr: 0.01000 - Train loss: 0.83902 - Test loss: 0.48006
# Epoch 78 - lr: 0.01000 - Train loss: 0.83873 - Test loss: 0.48104
# Epoch 79 - lr: 0.01000 - Train loss: 0.83844 - Test loss: 0.48201
# Epoch 80 - lr: 0.01000 - Train loss: 0.83815 - Test loss: 0.48299
# Epoch 81 - lr: 0.01000 - Train loss: 0.83788 - Test loss: 0.48396
# Epoch 82 - lr: 0.01000 - Train loss: 0.83760 - Test loss: 0.48493
# Epoch 83 - lr: 0.01000 - Train loss: 0.83733 - Test loss: 0.48590
# Epoch 84 - lr: 0.01000 - Train loss: 0.83707 - Test loss: 0.48686
# Epoch 85 - lr: 0.01000 - Train loss: 0.83681 - Test loss: 0.48783
# Epoch 86 - lr: 0.01000 - Train loss: 0.83656 - Test loss: 0.48879
# Epoch 87 - lr: 0.01000 - Train loss: 0.83631 - Test loss: 0.48975
# Epoch 88 - lr: 0.01000 - Train loss: 0.83606 - Test loss: 0.49070
# Epoch 89 - lr: 0.01000 - Train loss: 0.83582 - Test loss: 0.49166
# Epoch 90 - lr: 0.01000 - Train loss: 0.83558 - Test loss: 0.49261
# Epoch 91 - lr: 0.01000 - Train loss: 0.83534 - Test loss: 0.49355
# Epoch 92 - lr: 0.01000 - Train loss: 0.83511 - Test loss: 0.49450
# Epoch 93 - lr: 0.01000 - Train loss: 0.83488 - Test loss: 0.49544
# Epoch 94 - lr: 0.01000 - Train loss: 0.83465 - Test loss: 0.49638
# Epoch 95 - lr: 0.01000 - Train loss: 0.83443 - Test loss: 0.49732
# Epoch 96 - lr: 0.01000 - Train loss: 0.83421 - Test loss: 0.49825
# Epoch 97 - lr: 0.01000 - Train loss: 0.83399 - Test loss: 0.49919
# Epoch 98 - lr: 0.01000 - Train loss: 0.83377 - Test loss: 0.50011
# Epoch 99 - lr: 0.01000 - Train loss: 0.83356 - Test loss: 0.50104
# Epoch 100 - lr: 0.01000 - Train loss: 0.83335 - Test loss: 0.50196
# Epoch 101 - lr: 0.01000 - Train loss: 0.83314 - Test loss: 0.50288
# Epoch 102 - lr: 0.01000 - Train loss: 0.83294 - Test loss: 0.50380
# Epoch 103 - lr: 0.01000 - Train loss: 0.83273 - Test loss: 0.50471
# Epoch 104 - lr: 0.01000 - Train loss: 0.83253 - Test loss: 0.50562
# Epoch 105 - lr: 0.01000 - Train loss: 0.83233 - Test loss: 0.50652
# Epoch 106 - lr: 0.01000 - Train loss: 0.83213 - Test loss: 0.50742
# Epoch 107 - lr: 0.01000 - Train loss: 0.83193 - Test loss: 0.50832
# Epoch 108 - lr: 0.01000 - Train loss: 0.83174 - Test loss: 0.50921
# Epoch 109 - lr: 0.01000 - Train loss: 0.83154 - Test loss: 0.51010
# Epoch 110 - lr: 0.01000 - Train loss: 0.83135 - Test loss: 0.51099
# Epoch 111 - lr: 0.01000 - Train loss: 0.83116 - Test loss: 0.51187
# Epoch 112 - lr: 0.01000 - Train loss: 0.83097 - Test loss: 0.51274
# Epoch 113 - lr: 0.01000 - Train loss: 0.83078 - Test loss: 0.51362
# Epoch 114 - lr: 0.01000 - Train loss: 0.83060 - Test loss: 0.51449
# Epoch 115 - lr: 0.01000 - Train loss: 0.83041 - Test loss: 0.51535
# Epoch 116 - lr: 0.01000 - Train loss: 0.83023 - Test loss: 0.51621
# Epoch 117 - lr: 0.01000 - Train loss: 0.83004 - Test loss: 0.51706
# Epoch 118 - lr: 0.01000 - Train loss: 0.82986 - Test loss: 0.51791
# Epoch 119 - lr: 0.01000 - Train loss: 0.82968 - Test loss: 0.51876
# Epoch 120 - lr: 0.01000 - Train loss: 0.82949 - Test loss: 0.51960
# Epoch 121 - lr: 0.01000 - Train loss: 0.82931 - Test loss: 0.52043
# Epoch 122 - lr: 0.01000 - Train loss: 0.82913 - Test loss: 0.52126
# Epoch 123 - lr: 0.01000 - Train loss: 0.82895 - Test loss: 0.52209
# Epoch 124 - lr: 0.01000 - Train loss: 0.82877 - Test loss: 0.52291
# Epoch 125 - lr: 0.01000 - Train loss: 0.82859 - Test loss: 0.52372
# Epoch 126 - lr: 0.01000 - Train loss: 0.82842 - Test loss: 0.52453
# Epoch 127 - lr: 0.01000 - Train loss: 0.82824 - Test loss: 0.52533
# Epoch 128 - lr: 0.01000 - Train loss: 0.82806 - Test loss: 0.52613
# Epoch 129 - lr: 0.01000 - Train loss: 0.82788 - Test loss: 0.52692
# Epoch 130 - lr: 0.01000 - Train loss: 0.82771 - Test loss: 0.52770
# Epoch 131 - lr: 0.01000 - Train loss: 0.82753 - Test loss: 0.52848
# Epoch 132 - lr: 0.01000 - Train loss: 0.82735 - Test loss: 0.52926
# Epoch 133 - lr: 0.01000 - Train loss: 0.82718 - Test loss: 0.53002
# Epoch 134 - lr: 0.01000 - Train loss: 0.82700 - Test loss: 0.53078
# Epoch 135 - lr: 0.01000 - Train loss: 0.82683 - Test loss: 0.53154
# Epoch 136 - lr: 0.01000 - Train loss: 0.82665 - Test loss: 0.53229
# Epoch 137 - lr: 0.01000 - Train loss: 0.82648 - Test loss: 0.53303
# Epoch 138 - lr: 0.01000 - Train loss: 0.82630 - Test loss: 0.53376
# Epoch 139 - lr: 0.01000 - Train loss: 0.82612 - Test loss: 0.53449
# Epoch 140 - lr: 0.01000 - Train loss: 0.82595 - Test loss: 0.53521
# Epoch 141 - lr: 0.01000 - Train loss: 0.82577 - Test loss: 0.53593
# Epoch 142 - lr: 0.01000 - Train loss: 0.82560 - Test loss: 0.53663
# Epoch 143 - lr: 0.01000 - Train loss: 0.82542 - Test loss: 0.53733
# Epoch 144 - lr: 0.01000 - Train loss: 0.82524 - Test loss: 0.53803
# Epoch 145 - lr: 0.01000 - Train loss: 0.82507 - Test loss: 0.53871
# Epoch 146 - lr: 0.01000 - Train loss: 0.82489 - Test loss: 0.53939
# Epoch 147 - lr: 0.01000 - Train loss: 0.82472 - Test loss: 0.54007
# Epoch 148 - lr: 0.01000 - Train loss: 0.82454 - Test loss: 0.54073
# Epoch 149 - lr: 0.01000 - Train loss: 0.82436 - Test loss: 0.54139
# Epoch 150 - lr: 0.01000 - Train loss: 0.82418 - Test loss: 0.54204
# Epoch 151 - lr: 0.01000 - Train loss: 0.82401 - Test loss: 0.54268
# Epoch 152 - lr: 0.01000 - Train loss: 0.82383 - Test loss: 0.54331
# Epoch 153 - lr: 0.01000 - Train loss: 0.82365 - Test loss: 0.54394
# Epoch 154 - lr: 0.01000 - Train loss: 0.82347 - Test loss: 0.54456
# Epoch 155 - lr: 0.01000 - Train loss: 0.82329 - Test loss: 0.54517
# Epoch 156 - lr: 0.01000 - Train loss: 0.82312 - Test loss: 0.54577
# Epoch 157 - lr: 0.01000 - Train loss: 0.82294 - Test loss: 0.54637
# Epoch 158 - lr: 0.01000 - Train loss: 0.82276 - Test loss: 0.54695
# Epoch 159 - lr: 0.01000 - Train loss: 0.82258 - Test loss: 0.54753
# Epoch 160 - lr: 0.01000 - Train loss: 0.82240 - Test loss: 0.54810
# Epoch 161 - lr: 0.01000 - Train loss: 0.82221 - Test loss: 0.54867
# Epoch 162 - lr: 0.01000 - Train loss: 0.82203 - Test loss: 0.54922
# Epoch 163 - lr: 0.01000 - Train loss: 0.82185 - Test loss: 0.54977
# Epoch 164 - lr: 0.01000 - Train loss: 0.82167 - Test loss: 0.55030
# Epoch 165 - lr: 0.01000 - Train loss: 0.82149 - Test loss: 0.55083
# Epoch 166 - lr: 0.01000 - Train loss: 0.82130 - Test loss: 0.55135
# Epoch 167 - lr: 0.01000 - Train loss: 0.82112 - Test loss: 0.55187
# Epoch 168 - lr: 0.01000 - Train loss: 0.82094 - Test loss: 0.55237
# Epoch 169 - lr: 0.01000 - Train loss: 0.82075 - Test loss: 0.55286
# Epoch 170 - lr: 0.01000 - Train loss: 0.82057 - Test loss: 0.55335
# Epoch 171 - lr: 0.01000 - Train loss: 0.82038 - Test loss: 0.55383
# Epoch 172 - lr: 0.01000 - Train loss: 0.82020 - Test loss: 0.55430
# Epoch 173 - lr: 0.01000 - Train loss: 0.82001 - Test loss: 0.55476
# Epoch 174 - lr: 0.01000 - Train loss: 0.81982 - Test loss: 0.55521
# Epoch 175 - lr: 0.01000 - Train loss: 0.81964 - Test loss: 0.55566
# Epoch 176 - lr: 0.01000 - Train loss: 0.81945 - Test loss: 0.55609
# Epoch 177 - lr: 0.01000 - Train loss: 0.81926 - Test loss: 0.55652
# Epoch 178 - lr: 0.01000 - Train loss: 0.81907 - Test loss: 0.55693
# Epoch 179 - lr: 0.01000 - Train loss: 0.81888 - Test loss: 0.55734
# Epoch 180 - lr: 0.01000 - Train loss: 0.81869 - Test loss: 0.55774
# Epoch 181 - lr: 0.01000 - Train loss: 0.81850 - Test loss: 0.55813
# Epoch 182 - lr: 0.01000 - Train loss: 0.81831 - Test loss: 0.55851
# Epoch 183 - lr: 0.01000 - Train loss: 0.81812 - Test loss: 0.55889
# Epoch 184 - lr: 0.01000 - Train loss: 0.81793 - Test loss: 0.55925
# Epoch 185 - lr: 0.01000 - Train loss: 0.81773 - Test loss: 0.55960
# Epoch 186 - lr: 0.01000 - Train loss: 0.81754 - Test loss: 0.55995
# Epoch 187 - lr: 0.01000 - Train loss: 0.81735 - Test loss: 0.56029
# Epoch 188 - lr: 0.01000 - Train loss: 0.81715 - Test loss: 0.56062
# Epoch 189 - lr: 0.01000 - Train loss: 0.81696 - Test loss: 0.56093
# Epoch 190 - lr: 0.01000 - Train loss: 0.81676 - Test loss: 0.56124
# Epoch 191 - lr: 0.01000 - Train loss: 0.81657 - Test loss: 0.56155
# Epoch 192 - lr: 0.01000 - Train loss: 0.81637 - Test loss: 0.56184
# Epoch 193 - lr: 0.01000 - Train loss: 0.81618 - Test loss: 0.56212
# Epoch 194 - lr: 0.01000 - Train loss: 0.81598 - Test loss: 0.56240
# Epoch 195 - lr: 0.01000 - Train loss: 0.81578 - Test loss: 0.56266
# Epoch 196 - lr: 0.01000 - Train loss: 0.81558 - Test loss: 0.56292
# Epoch 197 - lr: 0.01000 - Train loss: 0.81538 - Test loss: 0.56317
# Epoch 198 - lr: 0.01000 - Train loss: 0.81518 - Test loss: 0.56341
# Epoch 199 - lr: 0.01000 - Train loss: 0.81498 - Test loss: 0.56364
# Epoch 200 - lr: 0.01000 - Train loss: 0.81478 - Test loss: 0.56386
# Epoch 201 - lr: 0.01000 - Train loss: 0.81458 - Test loss: 0.56407
# Epoch 202 - lr: 0.01000 - Train loss: 0.81438 - Test loss: 0.56428
# Epoch 203 - lr: 0.01000 - Train loss: 0.81418 - Test loss: 0.56447
# Epoch 204 - lr: 0.01000 - Train loss: 0.81398 - Test loss: 0.56466
# Epoch 205 - lr: 0.01000 - Train loss: 0.81377 - Test loss: 0.56483
# Epoch 206 - lr: 0.01000 - Train loss: 0.81357 - Test loss: 0.56500
# Epoch 207 - lr: 0.01000 - Train loss: 0.81337 - Test loss: 0.56516
# Epoch 208 - lr: 0.01000 - Train loss: 0.81316 - Test loss: 0.56532
# Epoch 209 - lr: 0.01000 - Train loss: 0.81296 - Test loss: 0.56546
# Epoch 210 - lr: 0.01000 - Train loss: 0.81275 - Test loss: 0.56559
# Epoch 211 - lr: 0.01000 - Train loss: 0.81255 - Test loss: 0.56572
# Epoch 212 - lr: 0.01000 - Train loss: 0.81234 - Test loss: 0.56584
# Epoch 213 - lr: 0.01000 - Train loss: 0.81213 - Test loss: 0.56594
# Epoch 214 - lr: 0.01000 - Train loss: 0.81192 - Test loss: 0.56604
# Epoch 215 - lr: 0.01000 - Train loss: 0.81172 - Test loss: 0.56614
# Epoch 216 - lr: 0.01000 - Train loss: 0.81151 - Test loss: 0.56622
# Epoch 217 - lr: 0.01000 - Train loss: 0.81130 - Test loss: 0.56630
# Epoch 218 - lr: 0.01000 - Train loss: 0.81109 - Test loss: 0.56636
# Epoch 219 - lr: 0.01000 - Train loss: 0.81088 - Test loss: 0.56642
# Epoch 220 - lr: 0.01000 - Train loss: 0.81067 - Test loss: 0.56647
# Epoch 221 - lr: 0.01000 - Train loss: 0.81046 - Test loss: 0.56651
# Epoch 222 - lr: 0.01000 - Train loss: 0.81024 - Test loss: 0.56655
# Epoch 223 - lr: 0.01000 - Train loss: 0.81003 - Test loss: 0.56657
# Epoch 224 - lr: 0.01000 - Train loss: 0.80982 - Test loss: 0.56659
# Epoch 225 - lr: 0.01000 - Train loss: 0.80961 - Test loss: 0.56660
# Epoch 226 - lr: 0.01000 - Train loss: 0.80939 - Test loss: 0.56660
# Epoch 227 - lr: 0.01000 - Train loss: 0.80918 - Test loss: 0.56660
# Epoch 228 - lr: 0.01000 - Train loss: 0.80896 - Test loss: 0.56658
# Epoch 229 - lr: 0.01000 - Train loss: 0.80875 - Test loss: 0.56656
# Epoch 230 - lr: 0.01000 - Train loss: 0.80853 - Test loss: 0.56653
# Epoch 231 - lr: 0.01000 - Train loss: 0.80832 - Test loss: 0.56650
# Epoch 232 - lr: 0.01000 - Train loss: 0.80810 - Test loss: 0.56645
# Epoch 233 - lr: 0.01000 - Train loss: 0.80788 - Test loss: 0.56640
# Epoch 234 - lr: 0.01000 - Train loss: 0.80766 - Test loss: 0.56634
# Epoch 235 - lr: 0.01000 - Train loss: 0.80745 - Test loss: 0.56627
# Epoch 236 - lr: 0.01000 - Train loss: 0.80723 - Test loss: 0.56620
# Epoch 237 - lr: 0.01000 - Train loss: 0.80701 - Test loss: 0.56612
# Epoch 238 - lr: 0.01000 - Train loss: 0.80679 - Test loss: 0.56603
# Epoch 239 - lr: 0.01000 - Train loss: 0.80657 - Test loss: 0.56593
# Epoch 240 - lr: 0.01000 - Train loss: 0.80635 - Test loss: 0.56583
# Epoch 241 - lr: 0.01000 - Train loss: 0.80613 - Test loss: 0.56572
# Epoch 242 - lr: 0.01000 - Train loss: 0.80590 - Test loss: 0.56560
# Epoch 243 - lr: 0.01000 - Train loss: 0.80568 - Test loss: 0.56547
# Epoch 244 - lr: 0.01000 - Train loss: 0.80546 - Test loss: 0.56534
# Epoch 245 - lr: 0.01000 - Train loss: 0.80524 - Test loss: 0.56520
# Epoch 246 - lr: 0.01000 - Train loss: 0.80501 - Test loss: 0.56506
# Epoch 247 - lr: 0.01000 - Train loss: 0.80479 - Test loss: 0.56491
# Epoch 248 - lr: 0.01000 - Train loss: 0.80456 - Test loss: 0.56475
# Epoch 249 - lr: 0.01000 - Train loss: 0.80434 - Test loss: 0.56458
# Epoch 250 - lr: 0.01000 - Train loss: 0.80411 - Test loss: 0.56441
# Epoch 251 - lr: 0.01000 - Train loss: 0.80389 - Test loss: 0.56423
# Epoch 252 - lr: 0.01000 - Train loss: 0.80366 - Test loss: 0.56405
# Epoch 253 - lr: 0.01000 - Train loss: 0.80343 - Test loss: 0.56385
# Epoch 254 - lr: 0.01000 - Train loss: 0.80321 - Test loss: 0.56366
# Epoch 255 - lr: 0.01000 - Train loss: 0.80298 - Test loss: 0.56345
# Epoch 256 - lr: 0.01000 - Train loss: 0.80275 - Test loss: 0.56324
# Epoch 257 - lr: 0.01000 - Train loss: 0.80252 - Test loss: 0.56302
# Epoch 258 - lr: 0.01000 - Train loss: 0.80229 - Test loss: 0.56280
# Epoch 259 - lr: 0.01000 - Train loss: 0.80206 - Test loss: 0.56257
# Epoch 260 - lr: 0.01000 - Train loss: 0.80183 - Test loss: 0.56234
# Epoch 261 - lr: 0.01000 - Train loss: 0.80160 - Test loss: 0.56210
# Epoch 262 - lr: 0.01000 - Train loss: 0.80137 - Test loss: 0.56185
# Epoch 263 - lr: 0.01000 - Train loss: 0.80114 - Test loss: 0.56160
# Epoch 264 - lr: 0.01000 - Train loss: 0.80091 - Test loss: 0.56134
# Epoch 265 - lr: 0.01000 - Train loss: 0.80068 - Test loss: 0.56108
# Epoch 266 - lr: 0.01000 - Train loss: 0.80044 - Test loss: 0.56081
# Epoch 267 - lr: 0.01000 - Train loss: 0.80021 - Test loss: 0.56054
# Epoch 268 - lr: 0.01000 - Train loss: 0.79997 - Test loss: 0.56026
# Epoch 269 - lr: 0.01000 - Train loss: 0.79974 - Test loss: 0.55997
# Epoch 270 - lr: 0.01000 - Train loss: 0.79951 - Test loss: 0.55968
# Epoch 271 - lr: 0.01000 - Train loss: 0.79927 - Test loss: 0.55939
# Epoch 272 - lr: 0.01000 - Train loss: 0.79903 - Test loss: 0.55908
# Epoch 273 - lr: 0.01000 - Train loss: 0.79880 - Test loss: 0.55878
# Epoch 274 - lr: 0.01000 - Train loss: 0.79856 - Test loss: 0.55847
# Epoch 275 - lr: 0.01000 - Train loss: 0.79832 - Test loss: 0.55815
# Epoch 276 - lr: 0.01000 - Train loss: 0.79809 - Test loss: 0.55783
# Epoch 277 - lr: 0.01000 - Train loss: 0.79785 - Test loss: 0.55751
# Epoch 278 - lr: 0.01000 - Train loss: 0.79761 - Test loss: 0.55718
# Epoch 279 - lr: 0.01000 - Train loss: 0.79737 - Test loss: 0.55684
# Epoch 280 - lr: 0.01000 - Train loss: 0.79713 - Test loss: 0.55650
# Epoch 281 - lr: 0.01000 - Train loss: 0.79689 - Test loss: 0.55616
# Epoch 282 - lr: 0.01000 - Train loss: 0.79665 - Test loss: 0.55581
# Epoch 283 - lr: 0.01000 - Train loss: 0.79641 - Test loss: 0.55545
# Epoch 284 - lr: 0.01000 - Train loss: 0.79617 - Test loss: 0.55510
# Epoch 285 - lr: 0.01000 - Train loss: 0.79593 - Test loss: 0.55474
# Epoch 286 - lr: 0.01000 - Train loss: 0.79568 - Test loss: 0.55437
# Epoch 287 - lr: 0.01000 - Train loss: 0.79544 - Test loss: 0.55400
# Epoch 288 - lr: 0.01000 - Train loss: 0.79520 - Test loss: 0.55362
# Epoch 289 - lr: 0.01000 - Train loss: 0.79495 - Test loss: 0.55325
# Epoch 290 - lr: 0.01000 - Train loss: 0.79471 - Test loss: 0.55286
# Epoch 291 - lr: 0.01000 - Train loss: 0.79447 - Test loss: 0.55248
# Epoch 292 - lr: 0.01000 - Train loss: 0.79422 - Test loss: 0.55209
# Epoch 293 - lr: 0.01000 - Train loss: 0.79397 - Test loss: 0.55169
# Epoch 294 - lr: 0.01000 - Train loss: 0.79373 - Test loss: 0.55129
# Epoch 295 - lr: 0.01000 - Train loss: 0.79348 - Test loss: 0.55089
# Epoch 296 - lr: 0.01000 - Train loss: 0.79323 - Test loss: 0.55049
# Epoch 297 - lr: 0.01000 - Train loss: 0.79299 - Test loss: 0.55008
# Epoch 298 - lr: 0.01000 - Train loss: 0.79274 - Test loss: 0.54967
# Epoch 299 - lr: 0.01000 - Train loss: 0.79249 - Test loss: 0.54925
# Epoch 300 - lr: 0.01000 - Train loss: 0.79224 - Test loss: 0.54883
# Epoch 301 - lr: 0.01000 - Train loss: 0.79199 - Test loss: 0.54841
# Epoch 302 - lr: 0.01000 - Train loss: 0.79174 - Test loss: 0.54798
# Epoch 303 - lr: 0.01000 - Train loss: 0.79149 - Test loss: 0.54756
# Epoch 304 - lr: 0.01000 - Train loss: 0.79124 - Test loss: 0.54712
# Epoch 305 - lr: 0.01000 - Train loss: 0.79099 - Test loss: 0.54669
# Epoch 306 - lr: 0.01000 - Train loss: 0.79074 - Test loss: 0.54625
# Epoch 307 - lr: 0.01000 - Train loss: 0.79048 - Test loss: 0.54581
# Epoch 308 - lr: 0.01000 - Train loss: 0.79023 - Test loss: 0.54536
# Epoch 309 - lr: 0.01000 - Train loss: 0.78998 - Test loss: 0.54492
# Epoch 310 - lr: 0.01000 - Train loss: 0.78972 - Test loss: 0.54447
# Epoch 311 - lr: 0.01000 - Train loss: 0.78947 - Test loss: 0.54402
# Epoch 312 - lr: 0.01000 - Train loss: 0.78921 - Test loss: 0.54356
# Epoch 313 - lr: 0.01000 - Train loss: 0.78896 - Test loss: 0.54310
# Epoch 314 - lr: 0.01000 - Train loss: 0.78870 - Test loss: 0.54264
# Epoch 315 - lr: 0.01000 - Train loss: 0.78845 - Test loss: 0.54218
# Epoch 316 - lr: 0.01000 - Train loss: 0.78819 - Test loss: 0.54171
# Epoch 317 - lr: 0.01000 - Train loss: 0.78793 - Test loss: 0.54124
# Epoch 318 - lr: 0.01000 - Train loss: 0.78767 - Test loss: 0.54077
# Epoch 319 - lr: 0.01000 - Train loss: 0.78741 - Test loss: 0.54030
# Epoch 320 - lr: 0.01000 - Train loss: 0.78715 - Test loss: 0.53983
# Epoch 321 - lr: 0.01000 - Train loss: 0.78690 - Test loss: 0.53935
# Epoch 322 - lr: 0.01000 - Train loss: 0.78664 - Test loss: 0.53887
# Epoch 323 - lr: 0.01000 - Train loss: 0.78637 - Test loss: 0.53839
# Epoch 324 - lr: 0.01000 - Train loss: 0.78611 - Test loss: 0.53790
# Epoch 325 - lr: 0.01000 - Train loss: 0.78585 - Test loss: 0.53742
# Epoch 326 - lr: 0.01000 - Train loss: 0.78559 - Test loss: 0.53693
# Epoch 327 - lr: 0.01000 - Train loss: 0.78533 - Test loss: 0.53644
# Epoch 328 - lr: 0.01000 - Train loss: 0.78506 - Test loss: 0.53595
# Epoch 329 - lr: 0.01000 - Train loss: 0.78480 - Test loss: 0.53546
# Epoch 330 - lr: 0.01000 - Train loss: 0.78454 - Test loss: 0.53496
# Epoch 331 - lr: 0.01000 - Train loss: 0.78427 - Test loss: 0.53446
# Epoch 332 - lr: 0.01000 - Train loss: 0.78401 - Test loss: 0.53396
# Epoch 333 - lr: 0.01000 - Train loss: 0.78374 - Test loss: 0.53346
# Epoch 334 - lr: 0.01000 - Train loss: 0.78347 - Test loss: 0.53296
# Epoch 335 - lr: 0.01000 - Train loss: 0.78321 - Test loss: 0.53246
# Epoch 336 - lr: 0.01000 - Train loss: 0.78294 - Test loss: 0.53195
# Epoch 337 - lr: 0.01000 - Train loss: 0.78267 - Test loss: 0.53145
# Epoch 338 - lr: 0.01000 - Train loss: 0.78240 - Test loss: 0.53094
# Epoch 339 - lr: 0.01000 - Train loss: 0.78213 - Test loss: 0.53043
# Epoch 340 - lr: 0.01000 - Train loss: 0.78186 - Test loss: 0.52992
# Epoch 341 - lr: 0.01000 - Train loss: 0.78159 - Test loss: 0.52940
# Epoch 342 - lr: 0.01000 - Train loss: 0.78132 - Test loss: 0.52889
# Epoch 343 - lr: 0.01000 - Train loss: 0.78105 - Test loss: 0.52838
# Epoch 344 - lr: 0.01000 - Train loss: 0.78078 - Test loss: 0.52786
# Epoch 345 - lr: 0.01000 - Train loss: 0.78050 - Test loss: 0.52734
# Epoch 346 - lr: 0.01000 - Train loss: 0.78023 - Test loss: 0.52682
# Epoch 347 - lr: 0.01000 - Train loss: 0.77996 - Test loss: 0.52630
# Epoch 348 - lr: 0.01000 - Train loss: 0.77968 - Test loss: 0.52578
# Epoch 349 - lr: 0.01000 - Train loss: 0.77941 - Test loss: 0.52526
# Epoch 350 - lr: 0.01000 - Train loss: 0.77913 - Test loss: 0.52474
# Epoch 351 - lr: 0.01000 - Train loss: 0.77886 - Test loss: 0.52422
# Epoch 352 - lr: 0.01000 - Train loss: 0.77858 - Test loss: 0.52369
# Epoch 353 - lr: 0.01000 - Train loss: 0.77830 - Test loss: 0.52317
# Epoch 354 - lr: 0.01000 - Train loss: 0.77803 - Test loss: 0.52264
# Epoch 355 - lr: 0.01000 - Train loss: 0.77775 - Test loss: 0.52211
# Epoch 356 - lr: 0.01000 - Train loss: 0.77747 - Test loss: 0.52158
# Epoch 357 - lr: 0.01000 - Train loss: 0.77719 - Test loss: 0.52106
# Epoch 358 - lr: 0.01000 - Train loss: 0.77691 - Test loss: 0.52053
# Epoch 359 - lr: 0.01000 - Train loss: 0.77663 - Test loss: 0.52000
# Epoch 360 - lr: 0.01000 - Train loss: 0.77635 - Test loss: 0.51947
# Epoch 361 - lr: 0.01000 - Train loss: 0.77606 - Test loss: 0.51893
# Epoch 362 - lr: 0.01000 - Train loss: 0.77578 - Test loss: 0.51840
# Epoch 363 - lr: 0.01000 - Train loss: 0.77550 - Test loss: 0.51787
# Epoch 364 - lr: 0.01000 - Train loss: 0.77521 - Test loss: 0.51734
# Epoch 365 - lr: 0.01000 - Train loss: 0.77493 - Test loss: 0.51680
# Epoch 366 - lr: 0.01000 - Train loss: 0.77464 - Test loss: 0.51627
# Epoch 367 - lr: 0.01000 - Train loss: 0.77436 - Test loss: 0.51573
# Epoch 368 - lr: 0.01000 - Train loss: 0.77407 - Test loss: 0.51520
# Epoch 369 - lr: 0.01000 - Train loss: 0.77378 - Test loss: 0.51466
# Epoch 370 - lr: 0.01000 - Train loss: 0.77350 - Test loss: 0.51413
# Epoch 371 - lr: 0.01000 - Train loss: 0.77321 - Test loss: 0.51359
# Epoch 372 - lr: 0.01000 - Train loss: 0.77292 - Test loss: 0.51306
# Epoch 373 - lr: 0.01000 - Train loss: 0.77263 - Test loss: 0.51252
# Epoch 374 - lr: 0.01000 - Train loss: 0.77234 - Test loss: 0.51198
# Epoch 375 - lr: 0.01000 - Train loss: 0.77205 - Test loss: 0.51145
# Epoch 376 - lr: 0.01000 - Train loss: 0.77176 - Test loss: 0.51091
# Epoch 377 - lr: 0.01000 - Train loss: 0.77146 - Test loss: 0.51037
# Epoch 378 - lr: 0.01000 - Train loss: 0.77117 - Test loss: 0.50983
# Epoch 379 - lr: 0.01000 - Train loss: 0.77088 - Test loss: 0.50930
# Epoch 380 - lr: 0.01000 - Train loss: 0.77058 - Test loss: 0.50876
# Epoch 381 - lr: 0.01000 - Train loss: 0.77029 - Test loss: 0.50822
# Epoch 382 - lr: 0.01000 - Train loss: 0.76999 - Test loss: 0.50768
# Epoch 383 - lr: 0.01000 - Train loss: 0.76969 - Test loss: 0.50714
# Epoch 384 - lr: 0.01000 - Train loss: 0.76940 - Test loss: 0.50661
# Epoch 385 - lr: 0.01000 - Train loss: 0.76910 - Test loss: 0.50607
# Epoch 386 - lr: 0.01000 - Train loss: 0.76880 - Test loss: 0.50553
# Epoch 387 - lr: 0.01000 - Train loss: 0.76850 - Test loss: 0.50499
# Epoch 388 - lr: 0.01000 - Train loss: 0.76820 - Test loss: 0.50445
# Epoch 389 - lr: 0.01000 - Train loss: 0.76790 - Test loss: 0.50392
# Epoch 390 - lr: 0.01000 - Train loss: 0.76760 - Test loss: 0.50338
# Epoch 391 - lr: 0.01000 - Train loss: 0.76730 - Test loss: 0.50284
# Epoch 392 - lr: 0.01000 - Train loss: 0.76699 - Test loss: 0.50230
# Epoch 393 - lr: 0.01000 - Train loss: 0.76669 - Test loss: 0.50177
# Epoch 394 - lr: 0.01000 - Train loss: 0.76639 - Test loss: 0.50123
# Epoch 395 - lr: 0.01000 - Train loss: 0.76608 - Test loss: 0.50069
# Epoch 396 - lr: 0.01000 - Train loss: 0.76577 - Test loss: 0.50015
# Epoch 397 - lr: 0.01000 - Train loss: 0.76547 - Test loss: 0.49962
# Epoch 398 - lr: 0.01000 - Train loss: 0.76516 - Test loss: 0.49908
# Epoch 399 - lr: 0.01000 - Train loss: 0.76485 - Test loss: 0.49854
# Epoch 400 - lr: 0.01000 - Train loss: 0.76454 - Test loss: 0.49801
# Epoch 401 - lr: 0.01000 - Train loss: 0.76423 - Test loss: 0.49747
# Epoch 402 - lr: 0.01000 - Train loss: 0.76392 - Test loss: 0.49694
# Epoch 403 - lr: 0.01000 - Train loss: 0.76361 - Test loss: 0.49640
# Epoch 404 - lr: 0.01000 - Train loss: 0.76330 - Test loss: 0.49587
# Epoch 405 - lr: 0.01000 - Train loss: 0.76299 - Test loss: 0.49533
# Epoch 406 - lr: 0.01000 - Train loss: 0.76267 - Test loss: 0.49480
# Epoch 407 - lr: 0.01000 - Train loss: 0.76236 - Test loss: 0.49426
# Epoch 408 - lr: 0.01000 - Train loss: 0.76204 - Test loss: 0.49373
# Epoch 409 - lr: 0.01000 - Train loss: 0.76172 - Test loss: 0.49320
# Epoch 410 - lr: 0.01000 - Train loss: 0.76141 - Test loss: 0.49266
# Epoch 411 - lr: 0.01000 - Train loss: 0.76109 - Test loss: 0.49213
# Epoch 412 - lr: 0.01000 - Train loss: 0.76077 - Test loss: 0.49160
# Epoch 413 - lr: 0.01000 - Train loss: 0.76045 - Test loss: 0.49107
# Epoch 414 - lr: 0.01000 - Train loss: 0.76013 - Test loss: 0.49053
# Epoch 415 - lr: 0.01000 - Train loss: 0.75981 - Test loss: 0.49000
# Epoch 416 - lr: 0.01000 - Train loss: 0.75949 - Test loss: 0.48947
# Epoch 417 - lr: 0.01000 - Train loss: 0.75916 - Test loss: 0.48894
# Epoch 418 - lr: 0.01000 - Train loss: 0.75884 - Test loss: 0.48841
# Epoch 419 - lr: 0.01000 - Train loss: 0.75851 - Test loss: 0.48788
# Epoch 420 - lr: 0.01000 - Train loss: 0.75819 - Test loss: 0.48736
# Epoch 421 - lr: 0.01000 - Train loss: 0.75786 - Test loss: 0.48683
# Epoch 422 - lr: 0.01000 - Train loss: 0.75753 - Test loss: 0.48630
# Epoch 423 - lr: 0.01000 - Train loss: 0.75720 - Test loss: 0.48577
# Epoch 424 - lr: 0.01000 - Train loss: 0.75687 - Test loss: 0.48525
# Epoch 425 - lr: 0.01000 - Train loss: 0.75654 - Test loss: 0.48472
# Epoch 426 - lr: 0.01000 - Train loss: 0.75621 - Test loss: 0.48419
# Epoch 427 - lr: 0.01000 - Train loss: 0.75588 - Test loss: 0.48367
# Epoch 428 - lr: 0.01000 - Train loss: 0.75555 - Test loss: 0.48314
# Epoch 429 - lr: 0.01000 - Train loss: 0.75521 - Test loss: 0.48262
# Epoch 430 - lr: 0.01000 - Train loss: 0.75488 - Test loss: 0.48210
# Epoch 431 - lr: 0.01000 - Train loss: 0.75454 - Test loss: 0.48157
# Epoch 432 - lr: 0.01000 - Train loss: 0.75420 - Test loss: 0.48105
# Epoch 433 - lr: 0.01000 - Train loss: 0.75387 - Test loss: 0.48053
# Epoch 434 - lr: 0.01000 - Train loss: 0.75353 - Test loss: 0.48001
# Epoch 435 - lr: 0.01000 - Train loss: 0.75319 - Test loss: 0.47948
# Epoch 436 - lr: 0.01000 - Train loss: 0.75284 - Test loss: 0.47896
# Epoch 437 - lr: 0.01000 - Train loss: 0.75250 - Test loss: 0.47844
# Epoch 438 - lr: 0.01000 - Train loss: 0.75216 - Test loss: 0.47793
# Epoch 439 - lr: 0.01000 - Train loss: 0.75181 - Test loss: 0.47741
# Epoch 440 - lr: 0.01000 - Train loss: 0.75147 - Test loss: 0.47689
# Epoch 441 - lr: 0.01000 - Train loss: 0.75112 - Test loss: 0.47637
# Epoch 442 - lr: 0.01000 - Train loss: 0.75077 - Test loss: 0.47585
# Epoch 443 - lr: 0.01000 - Train loss: 0.75043 - Test loss: 0.47534
# Epoch 444 - lr: 0.01000 - Train loss: 0.75008 - Test loss: 0.47482
# Epoch 445 - lr: 0.01000 - Train loss: 0.74972 - Test loss: 0.47430
# Epoch 446 - lr: 0.01000 - Train loss: 0.74937 - Test loss: 0.47379
# Epoch 447 - lr: 0.01000 - Train loss: 0.74902 - Test loss: 0.47328
# Epoch 448 - lr: 0.01000 - Train loss: 0.74866 - Test loss: 0.47276
# Epoch 449 - lr: 0.01000 - Train loss: 0.74831 - Test loss: 0.47225
# Epoch 450 - lr: 0.01000 - Train loss: 0.74795 - Test loss: 0.47174
# Epoch 451 - lr: 0.01000 - Train loss: 0.74759 - Test loss: 0.47122
# Epoch 452 - lr: 0.01000 - Train loss: 0.74724 - Test loss: 0.47071
# Epoch 453 - lr: 0.01000 - Train loss: 0.74688 - Test loss: 0.47020
# Epoch 454 - lr: 0.01000 - Train loss: 0.74651 - Test loss: 0.46969
# Epoch 455 - lr: 0.01000 - Train loss: 0.74615 - Test loss: 0.46918
# Epoch 456 - lr: 0.01000 - Train loss: 0.74579 - Test loss: 0.46867
# Epoch 457 - lr: 0.01000 - Train loss: 0.74542 - Test loss: 0.46816
# Epoch 458 - lr: 0.01000 - Train loss: 0.74506 - Test loss: 0.46765
# Epoch 459 - lr: 0.01000 - Train loss: 0.74469 - Test loss: 0.46715
# Epoch 460 - lr: 0.01000 - Train loss: 0.74432 - Test loss: 0.46664
# Epoch 461 - lr: 0.01000 - Train loss: 0.74395 - Test loss: 0.46613
# Epoch 462 - lr: 0.01000 - Train loss: 0.74358 - Test loss: 0.46563
# Epoch 463 - lr: 0.01000 - Train loss: 0.74321 - Test loss: 0.46512
# Epoch 464 - lr: 0.01000 - Train loss: 0.74283 - Test loss: 0.46462
# Epoch 465 - lr: 0.01000 - Train loss: 0.74246 - Test loss: 0.46411
# Epoch 466 - lr: 0.01000 - Train loss: 0.74208 - Test loss: 0.46361
# Epoch 467 - lr: 0.01000 - Train loss: 0.74170 - Test loss: 0.46310
# Epoch 468 - lr: 0.01000 - Train loss: 0.74132 - Test loss: 0.46260
# Epoch 469 - lr: 0.01000 - Train loss: 0.74094 - Test loss: 0.46210
# Epoch 470 - lr: 0.01000 - Train loss: 0.74056 - Test loss: 0.46160
# Epoch 471 - lr: 0.01000 - Train loss: 0.74018 - Test loss: 0.46109
# Epoch 472 - lr: 0.01000 - Train loss: 0.73979 - Test loss: 0.46059
# Epoch 473 - lr: 0.01000 - Train loss: 0.73941 - Test loss: 0.46009
# Epoch 474 - lr: 0.01000 - Train loss: 0.73902 - Test loss: 0.45959
# Epoch 475 - lr: 0.01000 - Train loss: 0.73863 - Test loss: 0.45909
# Epoch 476 - lr: 0.01000 - Train loss: 0.73824 - Test loss: 0.45859
# Epoch 477 - lr: 0.01000 - Train loss: 0.73785 - Test loss: 0.45809
# Epoch 478 - lr: 0.01000 - Train loss: 0.73746 - Test loss: 0.45760
# Epoch 479 - lr: 0.01000 - Train loss: 0.73706 - Test loss: 0.45710
# Epoch 480 - lr: 0.01000 - Train loss: 0.73666 - Test loss: 0.45660
# Epoch 481 - lr: 0.01000 - Train loss: 0.73627 - Test loss: 0.45610
# Epoch 482 - lr: 0.01000 - Train loss: 0.73587 - Test loss: 0.45561
# Epoch 483 - lr: 0.01000 - Train loss: 0.73547 - Test loss: 0.45511
# Epoch 484 - lr: 0.01000 - Train loss: 0.73506 - Test loss: 0.45462
# Epoch 485 - lr: 0.01000 - Train loss: 0.73466 - Test loss: 0.45412
# Epoch 486 - lr: 0.01000 - Train loss: 0.73425 - Test loss: 0.45362
# Epoch 487 - lr: 0.01000 - Train loss: 0.73385 - Test loss: 0.45313
# Epoch 488 - lr: 0.01000 - Train loss: 0.73344 - Test loss: 0.45264
# Epoch 489 - lr: 0.01000 - Train loss: 0.73303 - Test loss: 0.45214
# Epoch 490 - lr: 0.01000 - Train loss: 0.73261 - Test loss: 0.45165
# Epoch 491 - lr: 0.01000 - Train loss: 0.73220 - Test loss: 0.45115
# Epoch 492 - lr: 0.01000 - Train loss: 0.73178 - Test loss: 0.45066
# Epoch 493 - lr: 0.01000 - Train loss: 0.73137 - Test loss: 0.45017
# Epoch 494 - lr: 0.01000 - Train loss: 0.73095 - Test loss: 0.44968
# Epoch 495 - lr: 0.01000 - Train loss: 0.73053 - Test loss: 0.44918
# Epoch 496 - lr: 0.01000 - Train loss: 0.73010 - Test loss: 0.44869
# Epoch 497 - lr: 0.01000 - Train loss: 0.72968 - Test loss: 0.44820
# Epoch 498 - lr: 0.01000 - Train loss: 0.72925 - Test loss: 0.44771
# Epoch 499 - lr: 0.01000 - Train loss: 0.72883 - Test loss: 0.44722
# Epoch 500 - lr: 0.01000 - Train loss: 0.72840 - Test loss: 0.44673
# Epoch 501 - lr: 0.01000 - Train loss: 0.72796 - Test loss: 0.44624
# Epoch 502 - lr: 0.01000 - Train loss: 0.72753 - Test loss: 0.44575
# Epoch 503 - lr: 0.01000 - Train loss: 0.72709 - Test loss: 0.44526
# Epoch 504 - lr: 0.01000 - Train loss: 0.72666 - Test loss: 0.44476
# Epoch 505 - lr: 0.01000 - Train loss: 0.72622 - Test loss: 0.44427
# Epoch 506 - lr: 0.01000 - Train loss: 0.72578 - Test loss: 0.44379
# Epoch 507 - lr: 0.01000 - Train loss: 0.72533 - Test loss: 0.44330
# Epoch 508 - lr: 0.01000 - Train loss: 0.72489 - Test loss: 0.44281
# Epoch 509 - lr: 0.01000 - Train loss: 0.72444 - Test loss: 0.44232
# Epoch 510 - lr: 0.01000 - Train loss: 0.72399 - Test loss: 0.44183
# Epoch 511 - lr: 0.01000 - Train loss: 0.72354 - Test loss: 0.44134
# Epoch 512 - lr: 0.01000 - Train loss: 0.72309 - Test loss: 0.44085
# Epoch 513 - lr: 0.01000 - Train loss: 0.72263 - Test loss: 0.44036
# Epoch 514 - lr: 0.01000 - Train loss: 0.72217 - Test loss: 0.43987
# Epoch 515 - lr: 0.01000 - Train loss: 0.72171 - Test loss: 0.43938
# Epoch 516 - lr: 0.01000 - Train loss: 0.72125 - Test loss: 0.43889
# Epoch 517 - lr: 0.01000 - Train loss: 0.72079 - Test loss: 0.43840
# Epoch 518 - lr: 0.01000 - Train loss: 0.72032 - Test loss: 0.43791
# Epoch 519 - lr: 0.01000 - Train loss: 0.71985 - Test loss: 0.43743
# Epoch 520 - lr: 0.01000 - Train loss: 0.71938 - Test loss: 0.43694
# Epoch 521 - lr: 0.01000 - Train loss: 0.71891 - Test loss: 0.43645
# Epoch 522 - lr: 0.01000 - Train loss: 0.71844 - Test loss: 0.43596
# Epoch 523 - lr: 0.01000 - Train loss: 0.71796 - Test loss: 0.43547
# Epoch 524 - lr: 0.01000 - Train loss: 0.71748 - Test loss: 0.43498
# Epoch 525 - lr: 0.01000 - Train loss: 0.71700 - Test loss: 0.43449
# Epoch 526 - lr: 0.01000 - Train loss: 0.71651 - Test loss: 0.43400
# Epoch 527 - lr: 0.01000 - Train loss: 0.71602 - Test loss: 0.43351
# Epoch 528 - lr: 0.01000 - Train loss: 0.71553 - Test loss: 0.43302
# Epoch 529 - lr: 0.01000 - Train loss: 0.71504 - Test loss: 0.43253
# Epoch 530 - lr: 0.01000 - Train loss: 0.71455 - Test loss: 0.43204
# Epoch 531 - lr: 0.01000 - Train loss: 0.71405 - Test loss: 0.43155
# Epoch 532 - lr: 0.01000 - Train loss: 0.71355 - Test loss: 0.43106
# Epoch 533 - lr: 0.01000 - Train loss: 0.71305 - Test loss: 0.43056
# Epoch 534 - lr: 0.01000 - Train loss: 0.71254 - Test loss: 0.43007
# Epoch 535 - lr: 0.01000 - Train loss: 0.71204 - Test loss: 0.42958
# Epoch 536 - lr: 0.01000 - Train loss: 0.71153 - Test loss: 0.42909
# Epoch 537 - lr: 0.01000 - Train loss: 0.71101 - Test loss: 0.42860
# Epoch 538 - lr: 0.01000 - Train loss: 0.71050 - Test loss: 0.42810
# Epoch 539 - lr: 0.01000 - Train loss: 0.70998 - Test loss: 0.42761
# Epoch 540 - lr: 0.01000 - Train loss: 0.70946 - Test loss: 0.42712
# Epoch 541 - lr: 0.01000 - Train loss: 0.70894 - Test loss: 0.42662
# Epoch 542 - lr: 0.01000 - Train loss: 0.70841 - Test loss: 0.42613
# Epoch 543 - lr: 0.01000 - Train loss: 0.70788 - Test loss: 0.42563
# Epoch 544 - lr: 0.01000 - Train loss: 0.70735 - Test loss: 0.42514
# Epoch 545 - lr: 0.01000 - Train loss: 0.70681 - Test loss: 0.42464
# Epoch 546 - lr: 0.01000 - Train loss: 0.70627 - Test loss: 0.42414
# Epoch 547 - lr: 0.01000 - Train loss: 0.70573 - Test loss: 0.42365
# Epoch 548 - lr: 0.01000 - Train loss: 0.70519 - Test loss: 0.42315
# Epoch 549 - lr: 0.01000 - Train loss: 0.70464 - Test loss: 0.42265
# Epoch 550 - lr: 0.01000 - Train loss: 0.70409 - Test loss: 0.42215
# Epoch 551 - lr: 0.01000 - Train loss: 0.70354 - Test loss: 0.42165
# Epoch 552 - lr: 0.01000 - Train loss: 0.70298 - Test loss: 0.42115
# Epoch 553 - lr: 0.01000 - Train loss: 0.70242 - Test loss: 0.42065
# Epoch 554 - lr: 0.01000 - Train loss: 0.70186 - Test loss: 0.42015
# Epoch 555 - lr: 0.01000 - Train loss: 0.70129 - Test loss: 0.41964
# Epoch 556 - lr: 0.01000 - Train loss: 0.70072 - Test loss: 0.41914
# Epoch 557 - lr: 0.01000 - Train loss: 0.70015 - Test loss: 0.41864
# Epoch 558 - lr: 0.01000 - Train loss: 0.69957 - Test loss: 0.41813
# Epoch 559 - lr: 0.01000 - Train loss: 0.69899 - Test loss: 0.41763
# Epoch 560 - lr: 0.01000 - Train loss: 0.69841 - Test loss: 0.41712
# Epoch 561 - lr: 0.01000 - Train loss: 0.69783 - Test loss: 0.41661
# Epoch 562 - lr: 0.01000 - Train loss: 0.69724 - Test loss: 0.41610
# Epoch 563 - lr: 0.01000 - Train loss: 0.69664 - Test loss: 0.41559
# Epoch 564 - lr: 0.01000 - Train loss: 0.69604 - Test loss: 0.41508
# Epoch 565 - lr: 0.01000 - Train loss: 0.69544 - Test loss: 0.41457
# Epoch 566 - lr: 0.01000 - Train loss: 0.69484 - Test loss: 0.41406
# Epoch 567 - lr: 0.01000 - Train loss: 0.69423 - Test loss: 0.41355
# Epoch 568 - lr: 0.01000 - Train loss: 0.69362 - Test loss: 0.41303
# Epoch 569 - lr: 0.01000 - Train loss: 0.69300 - Test loss: 0.41252
# Epoch 570 - lr: 0.01000 - Train loss: 0.69238 - Test loss: 0.41200
# Epoch 571 - lr: 0.01000 - Train loss: 0.69176 - Test loss: 0.41148
# Epoch 572 - lr: 0.01000 - Train loss: 0.69113 - Test loss: 0.41096
# Epoch 573 - lr: 0.01000 - Train loss: 0.69050 - Test loss: 0.41044
# Epoch 574 - lr: 0.01000 - Train loss: 0.68987 - Test loss: 0.40992
# Epoch 575 - lr: 0.01000 - Train loss: 0.68923 - Test loss: 0.40940
# Epoch 576 - lr: 0.01000 - Train loss: 0.68858 - Test loss: 0.40887
# Epoch 577 - lr: 0.01000 - Train loss: 0.68793 - Test loss: 0.40835
# Epoch 578 - lr: 0.01000 - Train loss: 0.68728 - Test loss: 0.40782
# Epoch 579 - lr: 0.01000 - Train loss: 0.68663 - Test loss: 0.40729
# Epoch 580 - lr: 0.01000 - Train loss: 0.68597 - Test loss: 0.40676
# Epoch 581 - lr: 0.01000 - Train loss: 0.68530 - Test loss: 0.40623
# Epoch 582 - lr: 0.01000 - Train loss: 0.68463 - Test loss: 0.40570
# Epoch 583 - lr: 0.01000 - Train loss: 0.68396 - Test loss: 0.40516
# Epoch 584 - lr: 0.01000 - Train loss: 0.68328 - Test loss: 0.40462
# Epoch 585 - lr: 0.01000 - Train loss: 0.68260 - Test loss: 0.40409
# Epoch 586 - lr: 0.01000 - Train loss: 0.68191 - Test loss: 0.40355
# Epoch 587 - lr: 0.01000 - Train loss: 0.68122 - Test loss: 0.40301
# Epoch 588 - lr: 0.01000 - Train loss: 0.68052 - Test loss: 0.40246
# Epoch 589 - lr: 0.01000 - Train loss: 0.67982 - Test loss: 0.40192
# Epoch 590 - lr: 0.01000 - Train loss: 0.67911 - Test loss: 0.40137
# Epoch 591 - lr: 0.01000 - Train loss: 0.67840 - Test loss: 0.40083
# Epoch 592 - lr: 0.01000 - Train loss: 0.67769 - Test loss: 0.40028
# Epoch 593 - lr: 0.01000 - Train loss: 0.67697 - Test loss: 0.39972
# Epoch 594 - lr: 0.01000 - Train loss: 0.67624 - Test loss: 0.39917
# Epoch 595 - lr: 0.01000 - Train loss: 0.67551 - Test loss: 0.39861
# Epoch 596 - lr: 0.01000 - Train loss: 0.67477 - Test loss: 0.39806
# Epoch 597 - lr: 0.01000 - Train loss: 0.67403 - Test loss: 0.39750
# Epoch 598 - lr: 0.01000 - Train loss: 0.67328 - Test loss: 0.39694
# Epoch 599 - lr: 0.01000 - Train loss: 0.67253 - Test loss: 0.39637
# Epoch 600 - lr: 0.01000 - Train loss: 0.67177 - Test loss: 0.39581
# Epoch 601 - lr: 0.01000 - Train loss: 0.67101 - Test loss: 0.39524
# Epoch 602 - lr: 0.01000 - Train loss: 0.67024 - Test loss: 0.39467
# Epoch 603 - lr: 0.01000 - Train loss: 0.66947 - Test loss: 0.39409
# Epoch 604 - lr: 0.01000 - Train loss: 0.66869 - Test loss: 0.39352
# Epoch 605 - lr: 0.01000 - Train loss: 0.66790 - Test loss: 0.39294
# Epoch 606 - lr: 0.01000 - Train loss: 0.66711 - Test loss: 0.39236
# Epoch 607 - lr: 0.01000 - Train loss: 0.66632 - Test loss: 0.39178
# Epoch 608 - lr: 0.01000 - Train loss: 0.66551 - Test loss: 0.39120
# Epoch 609 - lr: 0.01000 - Train loss: 0.66470 - Test loss: 0.39061
# Epoch 610 - lr: 0.01000 - Train loss: 0.66389 - Test loss: 0.39002
# Epoch 611 - lr: 0.01000 - Train loss: 0.66307 - Test loss: 0.38943
# Epoch 612 - lr: 0.01000 - Train loss: 0.66224 - Test loss: 0.38883
# Epoch 613 - lr: 0.01000 - Train loss: 0.66141 - Test loss: 0.38823
# Epoch 614 - lr: 0.01000 - Train loss: 0.66057 - Test loss: 0.38763
# Epoch 615 - lr: 0.01000 - Train loss: 0.65972 - Test loss: 0.38703
# Epoch 616 - lr: 0.01000 - Train loss: 0.65887 - Test loss: 0.38642
# Epoch 617 - lr: 0.01000 - Train loss: 0.65801 - Test loss: 0.38582
# Epoch 618 - lr: 0.01000 - Train loss: 0.65714 - Test loss: 0.38520
# Epoch 619 - lr: 0.01000 - Train loss: 0.65627 - Test loss: 0.38459
# Epoch 620 - lr: 0.01000 - Train loss: 0.65539 - Test loss: 0.38397
# Epoch 621 - lr: 0.01000 - Train loss: 0.65450 - Test loss: 0.38335
# Epoch 622 - lr: 0.01000 - Train loss: 0.65361 - Test loss: 0.38273
# Epoch 623 - lr: 0.01000 - Train loss: 0.65271 - Test loss: 0.38210
# Epoch 624 - lr: 0.01000 - Train loss: 0.65180 - Test loss: 0.38147
# Epoch 625 - lr: 0.01000 - Train loss: 0.65089 - Test loss: 0.38083
# Epoch 626 - lr: 0.01000 - Train loss: 0.64997 - Test loss: 0.38020
# Epoch 627 - lr: 0.01000 - Train loss: 0.64904 - Test loss: 0.37956
# Epoch 628 - lr: 0.01000 - Train loss: 0.64810 - Test loss: 0.37891
# Epoch 629 - lr: 0.01000 - Train loss: 0.64716 - Test loss: 0.37827
# Epoch 630 - lr: 0.01000 - Train loss: 0.64620 - Test loss: 0.37761
# Epoch 631 - lr: 0.01000 - Train loss: 0.64524 - Test loss: 0.37696
# Epoch 632 - lr: 0.01000 - Train loss: 0.64428 - Test loss: 0.37630
# Epoch 633 - lr: 0.01000 - Train loss: 0.64330 - Test loss: 0.37564
# Epoch 634 - lr: 0.01000 - Train loss: 0.64232 - Test loss: 0.37497
# Epoch 635 - lr: 0.01000 - Train loss: 0.64133 - Test loss: 0.37431
# Epoch 636 - lr: 0.01000 - Train loss: 0.64033 - Test loss: 0.37363
# Epoch 637 - lr: 0.01000 - Train loss: 0.63932 - Test loss: 0.37295
# Epoch 638 - lr: 0.01000 - Train loss: 0.63830 - Test loss: 0.37227
# Epoch 639 - lr: 0.01000 - Train loss: 0.63728 - Test loss: 0.37159
# Epoch 640 - lr: 0.01000 - Train loss: 0.63624 - Test loss: 0.37090
# Epoch 641 - lr: 0.01000 - Train loss: 0.63520 - Test loss: 0.37020
# Epoch 642 - lr: 0.01000 - Train loss: 0.63415 - Test loss: 0.36951
# Epoch 643 - lr: 0.01000 - Train loss: 0.63309 - Test loss: 0.36880
# Epoch 644 - lr: 0.01000 - Train loss: 0.63202 - Test loss: 0.36810
# Epoch 645 - lr: 0.01000 - Train loss: 0.63095 - Test loss: 0.36739
# Epoch 646 - lr: 0.01000 - Train loss: 0.62986 - Test loss: 0.36667
# Epoch 647 - lr: 0.01000 - Train loss: 0.62876 - Test loss: 0.36595
# Epoch 648 - lr: 0.01000 - Train loss: 0.62766 - Test loss: 0.36523
# Epoch 649 - lr: 0.01000 - Train loss: 0.62654 - Test loss: 0.36450
# Epoch 650 - lr: 0.01000 - Train loss: 0.62542 - Test loss: 0.36376
# Epoch 651 - lr: 0.01000 - Train loss: 0.62428 - Test loss: 0.36302
# Epoch 652 - lr: 0.01000 - Train loss: 0.62314 - Test loss: 0.36228
# Epoch 653 - lr: 0.01000 - Train loss: 0.62198 - Test loss: 0.36153
# Epoch 654 - lr: 0.01000 - Train loss: 0.62082 - Test loss: 0.36078
# Epoch 655 - lr: 0.01000 - Train loss: 0.61965 - Test loss: 0.36002
# Epoch 656 - lr: 0.01000 - Train loss: 0.61846 - Test loss: 0.35925
# Epoch 657 - lr: 0.01000 - Train loss: 0.61727 - Test loss: 0.35849
# Epoch 658 - lr: 0.01000 - Train loss: 0.61606 - Test loss: 0.35771
# Epoch 659 - lr: 0.01000 - Train loss: 0.61484 - Test loss: 0.35693
# Epoch 660 - lr: 0.01000 - Train loss: 0.61362 - Test loss: 0.35615
# Epoch 661 - lr: 0.01000 - Train loss: 0.61238 - Test loss: 0.35535
# Epoch 662 - lr: 0.01000 - Train loss: 0.61113 - Test loss: 0.35456
# Epoch 663 - lr: 0.01000 - Train loss: 0.60987 - Test loss: 0.35376
# Epoch 664 - lr: 0.01000 - Train loss: 0.60860 - Test loss: 0.35295
# Epoch 665 - lr: 0.01000 - Train loss: 0.60731 - Test loss: 0.35213
# Epoch 666 - lr: 0.01000 - Train loss: 0.60602 - Test loss: 0.35131
# Epoch 667 - lr: 0.01000 - Train loss: 0.60471 - Test loss: 0.35049
# Epoch 668 - lr: 0.01000 - Train loss: 0.60339 - Test loss: 0.34966
# Epoch 669 - lr: 0.01000 - Train loss: 0.60206 - Test loss: 0.34882
# Epoch 670 - lr: 0.01000 - Train loss: 0.60072 - Test loss: 0.34797
# Epoch 671 - lr: 0.01000 - Train loss: 0.59937 - Test loss: 0.34712
# Epoch 672 - lr: 0.01000 - Train loss: 0.59800 - Test loss: 0.34627
# Epoch 673 - lr: 0.01000 - Train loss: 0.59662 - Test loss: 0.34540
# Epoch 674 - lr: 0.01000 - Train loss: 0.59523 - Test loss: 0.34453
# Epoch 675 - lr: 0.01000 - Train loss: 0.59382 - Test loss: 0.34366
# Epoch 676 - lr: 0.01000 - Train loss: 0.59241 - Test loss: 0.34277
# Epoch 677 - lr: 0.01000 - Train loss: 0.59098 - Test loss: 0.34188
# Epoch 678 - lr: 0.01000 - Train loss: 0.58953 - Test loss: 0.34099
# Epoch 679 - lr: 0.01000 - Train loss: 0.58807 - Test loss: 0.34008
# Epoch 680 - lr: 0.01000 - Train loss: 0.58660 - Test loss: 0.33917
# Epoch 681 - lr: 0.01000 - Train loss: 0.58512 - Test loss: 0.33825
# Epoch 682 - lr: 0.01000 - Train loss: 0.58362 - Test loss: 0.33733
# Epoch 683 - lr: 0.01000 - Train loss: 0.58211 - Test loss: 0.33639
# Epoch 684 - lr: 0.01000 - Train loss: 0.58058 - Test loss: 0.33545
# Epoch 685 - lr: 0.01000 - Train loss: 0.57904 - Test loss: 0.33451
# Epoch 686 - lr: 0.01000 - Train loss: 0.57749 - Test loss: 0.33355
# Epoch 687 - lr: 0.01000 - Train loss: 0.57592 - Test loss: 0.33259
# Epoch 688 - lr: 0.01000 - Train loss: 0.57434 - Test loss: 0.33162
# Epoch 689 - lr: 0.01000 - Train loss: 0.57274 - Test loss: 0.33064
# Epoch 690 - lr: 0.01000 - Train loss: 0.57112 - Test loss: 0.32965
# Epoch 691 - lr: 0.01000 - Train loss: 0.56949 - Test loss: 0.32866
# Epoch 692 - lr: 0.01000 - Train loss: 0.56785 - Test loss: 0.32765
# Epoch 693 - lr: 0.01000 - Train loss: 0.56619 - Test loss: 0.32664
# Epoch 694 - lr: 0.01000 - Train loss: 0.56451 - Test loss: 0.32562
# Epoch 695 - lr: 0.01000 - Train loss: 0.56282 - Test loss: 0.32459
# Epoch 696 - lr: 0.01000 - Train loss: 0.56112 - Test loss: 0.32356
# Epoch 697 - lr: 0.01000 - Train loss: 0.55939 - Test loss: 0.32251
# Epoch 698 - lr: 0.01000 - Train loss: 0.55765 - Test loss: 0.32146
# Epoch 699 - lr: 0.01000 - Train loss: 0.55590 - Test loss: 0.32040
# Epoch 700 - lr: 0.01000 - Train loss: 0.55413 - Test loss: 0.31932
# Epoch 701 - lr: 0.01000 - Train loss: 0.55234 - Test loss: 0.31824
# Epoch 702 - lr: 0.01000 - Train loss: 0.55053 - Test loss: 0.31715
# Epoch 703 - lr: 0.01000 - Train loss: 0.54871 - Test loss: 0.31606
# Epoch 704 - lr: 0.01000 - Train loss: 0.54687 - Test loss: 0.31495
# Epoch 705 - lr: 0.01000 - Train loss: 0.54501 - Test loss: 0.31383
# Epoch 706 - lr: 0.01000 - Train loss: 0.54314 - Test loss: 0.31270
# Epoch 707 - lr: 0.01000 - Train loss: 0.54124 - Test loss: 0.31157
# Epoch 708 - lr: 0.01000 - Train loss: 0.53933 - Test loss: 0.31042
# Epoch 709 - lr: 0.01000 - Train loss: 0.53741 - Test loss: 0.30926
# Epoch 710 - lr: 0.01000 - Train loss: 0.53546 - Test loss: 0.30810
# Epoch 711 - lr: 0.01000 - Train loss: 0.53349 - Test loss: 0.30692
# Epoch 712 - lr: 0.01000 - Train loss: 0.53151 - Test loss: 0.30574
# Epoch 713 - lr: 0.01000 - Train loss: 0.52951 - Test loss: 0.30454
# Epoch 714 - lr: 0.01000 - Train loss: 0.52749 - Test loss: 0.30333
# Epoch 715 - lr: 0.01000 - Train loss: 0.52545 - Test loss: 0.30212
# Epoch 716 - lr: 0.01000 - Train loss: 0.52339 - Test loss: 0.30089
# Epoch 717 - lr: 0.01000 - Train loss: 0.52131 - Test loss: 0.29965
# Epoch 718 - lr: 0.01000 - Train loss: 0.51922 - Test loss: 0.29841
# ...
# Epoch 4766 - lr: 0.01000 - Train loss: 0.04354 - Test loss: 0.05155
# Epoch 4767 - lr: 0.01000 - Train loss: 0.04354 - Test loss: 0.05155
# Epoch 4768 - lr: 0.01000 - Train loss: 0.04353 - Test loss: 0.05155
# Epoch 4769 - lr: 0.01000 - Train loss: 0.04353 - Test loss: 0.05155
# Epoch 4770 - lr: 0.01000 - Train loss: 0.04353 - Test loss: 0.05155
# Epoch 4771 - lr: 0.01000 - Train loss: 0.04352 - Test loss: 0.05155
# Epoch 4772 - lr: 0.01000 - Train loss: 0.04352 - Test loss: 0.05155
# Epoch 4773 - lr: 0.01000 - Train loss: 0.04352 - Test loss: 0.05155
# Epoch 4774 - lr: 0.01000 - Train loss: 0.04352 - Test loss: 0.05155
# Epoch 4775 - lr: 0.01000 - Train loss: 0.04351 - Test loss: 0.05155
# Epoch 4776 - lr: 0.01000 - Train loss: 0.04351 - Test loss: 0.05155
# Epoch 4777 - lr: 0.01000 - Train loss: 0.04351 - Test loss: 0.05155
# Epoch 4778 - lr: 0.01000 - Train loss: 0.04351 - Test loss: 0.05155
# Epoch 4779 - lr: 0.01000 - Train loss: 0.04350 - Test loss: 0.05155
# Epoch 4780 - lr: 0.01000 - Train loss: 0.04350 - Test loss: 0.05155
# Epoch 4781 - lr: 0.01000 - Train loss: 0.04350 - Test loss: 0.05155
# Epoch 4782 - lr: 0.01000 - Train loss: 0.04349 - Test loss: 0.05155
# Epoch 4783 - lr: 0.01000 - Train loss: 0.04349 - Test loss: 0.05155
# Epoch 4784 - lr: 0.01000 - Train loss: 0.04349 - Test loss: 0.05155
# Epoch 4785 - lr: 0.01000 - Train loss: 0.04349 - Test loss: 0.05155
# Epoch 4786 - lr: 0.01000 - Train loss: 0.04348 - Test loss: 0.05155
# Epoch 4787 - lr: 0.01000 - Train loss: 0.04348 - Test loss: 0.05155
# Epoch 4788 - lr: 0.01000 - Train loss: 0.04348 - Test loss: 0.05155
# Epoch 4789 - lr: 0.01000 - Train loss: 0.04347 - Test loss: 0.05155
# Epoch 4790 - lr: 0.01000 - Train loss: 0.04347 - Test loss: 0.05155
# Epoch 4791 - lr: 0.01000 - Train loss: 0.04347 - Test loss: 0.05155
# Epoch 4792 - lr: 0.01000 - Train loss: 0.04347 - Test loss: 0.05155
# Epoch 4793 - lr: 0.01000 - Train loss: 0.04346 - Test loss: 0.05155
# Epoch 4794 - lr: 0.01000 - Train loss: 0.04346 - Test loss: 0.05155
# Epoch 4795 - lr: 0.01000 - Train loss: 0.04346 - Test loss: 0.05155
# Epoch 4796 - lr: 0.01000 - Train loss: 0.04345 - Test loss: 0.05155
# Epoch 4797 - lr: 0.01000 - Train loss: 0.04345 - Test loss: 0.05155
# Epoch 4798 - lr: 0.01000 - Train loss: 0.04345 - Test loss: 0.05155
# Epoch 4799 - lr: 0.01000 - Train loss: 0.04345 - Test loss: 0.05156
# Epoch 4800 - lr: 0.01000 - Train loss: 0.04344 - Test loss: 0.05156
# Epoch 4801 - lr: 0.01000 - Train loss: 0.04344 - Test loss: 0.05156
# Epoch 4802 - lr: 0.01000 - Train loss: 0.04344 - Test loss: 0.05156
# Epoch 4803 - lr: 0.01000 - Train loss: 0.04343 - Test loss: 0.05156
# Epoch 4804 - lr: 0.01000 - Train loss: 0.04343 - Test loss: 0.05156
# Epoch 4805 - lr: 0.01000 - Train loss: 0.04343 - Test loss: 0.05156
# Epoch 4806 - lr: 0.01000 - Train loss: 0.04343 - Test loss: 0.05156
# Epoch 4807 - lr: 0.01000 - Train loss: 0.04342 - Test loss: 0.05156
# Epoch 4808 - lr: 0.01000 - Train loss: 0.04342 - Test loss: 0.05156
# Epoch 4809 - lr: 0.01000 - Train loss: 0.04342 - Test loss: 0.05156
# Epoch 4810 - lr: 0.01000 - Train loss: 0.04341 - Test loss: 0.05156
# Epoch 4811 - lr: 0.01000 - Train loss: 0.04341 - Test loss: 0.05156
# Epoch 4812 - lr: 0.01000 - Train loss: 0.04341 - Test loss: 0.05156
# Epoch 4813 - lr: 0.01000 - Train loss: 0.04341 - Test loss: 0.05156
# Epoch 4814 - lr: 0.01000 - Train loss: 0.04340 - Test loss: 0.05156
# Epoch 4815 - lr: 0.01000 - Train loss: 0.04340 - Test loss: 0.05156
# Epoch 4816 - lr: 0.01000 - Train loss: 0.04340 - Test loss: 0.05156
# Epoch 4817 - lr: 0.01000 - Train loss: 0.04340 - Test loss: 0.05156
# Epoch 4818 - lr: 0.01000 - Train loss: 0.04339 - Test loss: 0.05156
# Epoch 4819 - lr: 0.01000 - Train loss: 0.04339 - Test loss: 0.05156
# Epoch 4820 - lr: 0.01000 - Train loss: 0.04339 - Test loss: 0.05156
# Epoch 4821 - lr: 0.01000 - Train loss: 0.04338 - Test loss: 0.05156
# Epoch 4822 - lr: 0.01000 - Train loss: 0.04338 - Test loss: 0.05156
# Epoch 4823 - lr: 0.01000 - Train loss: 0.04338 - Test loss: 0.05156
# Epoch 4824 - lr: 0.01000 - Train loss: 0.04338 - Test loss: 0.05156
# Epoch 4825 - lr: 0.01000 - Train loss: 0.04337 - Test loss: 0.05156
# Epoch 4826 - lr: 0.01000 - Train loss: 0.04337 - Test loss: 0.05156
# Epoch 4827 - lr: 0.01000 - Train loss: 0.04337 - Test loss: 0.05156
# Epoch 4828 - lr: 0.01000 - Train loss: 0.04336 - Test loss: 0.05156
# Epoch 4829 - lr: 0.01000 - Train loss: 0.04336 - Test loss: 0.05156
# Epoch 4830 - lr: 0.01000 - Train loss: 0.04336 - Test loss: 0.05156
# Epoch 4831 - lr: 0.01000 - Train loss: 0.04336 - Test loss: 0.05156
# Epoch 4832 - lr: 0.01000 - Train loss: 0.04335 - Test loss: 0.05156
# Epoch 4833 - lr: 0.01000 - Train loss: 0.04335 - Test loss: 0.05156
# Epoch 4834 - lr: 0.01000 - Train loss: 0.04335 - Test loss: 0.05156
# Epoch 4835 - lr: 0.01000 - Train loss: 0.04334 - Test loss: 0.05156
# Epoch 4836 - lr: 0.01000 - Train loss: 0.04334 - Test loss: 0.05156
# Epoch 4837 - lr: 0.01000 - Train loss: 0.04334 - Test loss: 0.05156
# Epoch 4838 - lr: 0.01000 - Train loss: 0.04334 - Test loss: 0.05156
# Epoch 4839 - lr: 0.01000 - Train loss: 0.04333 - Test loss: 0.05156
# Epoch 4840 - lr: 0.01000 - Train loss: 0.04333 - Test loss: 0.05156
# Epoch 4841 - lr: 0.01000 - Train loss: 0.04333 - Test loss: 0.05156
# Epoch 4842 - lr: 0.01000 - Train loss: 0.04332 - Test loss: 0.05156
# Epoch 4843 - lr: 0.01000 - Train loss: 0.04332 - Test loss: 0.05157
# Epoch 4844 - lr: 0.01000 - Train loss: 0.04332 - Test loss: 0.05157
# Epoch 4845 - lr: 0.01000 - Train loss: 0.04332 - Test loss: 0.05157
# Epoch 4846 - lr: 0.01000 - Train loss: 0.04331 - Test loss: 0.05157
# Epoch 4847 - lr: 0.01000 - Train loss: 0.04331 - Test loss: 0.05157
# Epoch 4848 - lr: 0.01000 - Train loss: 0.04331 - Test loss: 0.05157
# Epoch 4849 - lr: 0.01000 - Train loss: 0.04330 - Test loss: 0.05157
# Epoch 4850 - lr: 0.01000 - Train loss: 0.04330 - Test loss: 0.05157
# Epoch 4851 - lr: 0.01000 - Train loss: 0.04330 - Test loss: 0.05157
# Epoch 4852 - lr: 0.01000 - Train loss: 0.04330 - Test loss: 0.05157
# Epoch 4853 - lr: 0.01000 - Train loss: 0.04329 - Test loss: 0.05157
# Epoch 4854 - lr: 0.01000 - Train loss: 0.04329 - Test loss: 0.05157
# Epoch 4855 - lr: 0.01000 - Train loss: 0.04329 - Test loss: 0.05157
# Epoch 4856 - lr: 0.01000 - Train loss: 0.04328 - Test loss: 0.05157
# Epoch 4857 - lr: 0.01000 - Train loss: 0.04328 - Test loss: 0.05157
# Epoch 4858 - lr: 0.01000 - Train loss: 0.04328 - Test loss: 0.05157
# Epoch 4859 - lr: 0.01000 - Train loss: 0.04328 - Test loss: 0.05157
# Epoch 4860 - lr: 0.01000 - Train loss: 0.04327 - Test loss: 0.05157
# Epoch 4861 - lr: 0.01000 - Train loss: 0.04327 - Test loss: 0.05157
# Epoch 4862 - lr: 0.01000 - Train loss: 0.04327 - Test loss: 0.05157
# Epoch 4863 - lr: 0.01000 - Train loss: 0.04326 - Test loss: 0.05157
# Epoch 4864 - lr: 0.01000 - Train loss: 0.04326 - Test loss: 0.05157
# Epoch 4865 - lr: 0.01000 - Train loss: 0.04326 - Test loss: 0.05157
# Epoch 4866 - lr: 0.01000 - Train loss: 0.04326 - Test loss: 0.05157
# Epoch 4867 - lr: 0.01000 - Train loss: 0.04325 - Test loss: 0.05157
# Epoch 4868 - lr: 0.01000 - Train loss: 0.04325 - Test loss: 0.05157
# Epoch 4869 - lr: 0.01000 - Train loss: 0.04325 - Test loss: 0.05157
# Epoch 4870 - lr: 0.01000 - Train loss: 0.04324 - Test loss: 0.05157
# Epoch 4871 - lr: 0.01000 - Train loss: 0.04324 - Test loss: 0.05157
# Epoch 4872 - lr: 0.01000 - Train loss: 0.04324 - Test loss: 0.05157
# Epoch 4873 - lr: 0.01000 - Train loss: 0.04324 - Test loss: 0.05157
# Epoch 4874 - lr: 0.01000 - Train loss: 0.04323 - Test loss: 0.05157
# Epoch 4875 - lr: 0.01000 - Train loss: 0.04323 - Test loss: 0.05157
# Epoch 4876 - lr: 0.01000 - Train loss: 0.04323 - Test loss: 0.05157
# Epoch 4877 - lr: 0.01000 - Train loss: 0.04322 - Test loss: 0.05157
# Epoch 4878 - lr: 0.01000 - Train loss: 0.04322 - Test loss: 0.05157
# Epoch 4879 - lr: 0.01000 - Train loss: 0.04322 - Test loss: 0.05157
# Epoch 4880 - lr: 0.01000 - Train loss: 0.04322 - Test loss: 0.05157
# Epoch 4881 - lr: 0.01000 - Train loss: 0.04321 - Test loss: 0.05157
# Epoch 4882 - lr: 0.01000 - Train loss: 0.04321 - Test loss: 0.05157
# Epoch 4883 - lr: 0.01000 - Train loss: 0.04321 - Test loss: 0.05157
# Epoch 4884 - lr: 0.01000 - Train loss: 0.04320 - Test loss: 0.05157
# Epoch 4885 - lr: 0.01000 - Train loss: 0.04320 - Test loss: 0.05157
# Epoch 4886 - lr: 0.01000 - Train loss: 0.04320 - Test loss: 0.05157
# Epoch 4887 - lr: 0.01000 - Train loss: 0.04320 - Test loss: 0.05157
# Epoch 4888 - lr: 0.01000 - Train loss: 0.04319 - Test loss: 0.05157
# Epoch 4889 - lr: 0.01000 - Train loss: 0.04319 - Test loss: 0.05157
# Epoch 4890 - lr: 0.01000 - Train loss: 0.04319 - Test loss: 0.05157
# Epoch 4891 - lr: 0.01000 - Train loss: 0.04318 - Test loss: 0.05157
# Epoch 4892 - lr: 0.01000 - Train loss: 0.04318 - Test loss: 0.05158
# Epoch 4893 - lr: 0.01000 - Train loss: 0.04318 - Test loss: 0.05158
# Epoch 4894 - lr: 0.01000 - Train loss: 0.04318 - Test loss: 0.05158
# Epoch 4895 - lr: 0.01000 - Train loss: 0.04317 - Test loss: 0.05158
# Epoch 4896 - lr: 0.01000 - Train loss: 0.04317 - Test loss: 0.05158
# Epoch 4897 - lr: 0.01000 - Train loss: 0.04317 - Test loss: 0.05158
# Epoch 4898 - lr: 0.01000 - Train loss: 0.04316 - Test loss: 0.05158
# Epoch 4899 - lr: 0.01000 - Train loss: 0.04316 - Test loss: 0.05158
# Epoch 4900 - lr: 0.01000 - Train loss: 0.04316 - Test loss: 0.05158
# Epoch 4901 - lr: 0.01000 - Train loss: 0.04316 - Test loss: 0.05158
# Epoch 4902 - lr: 0.01000 - Train loss: 0.04315 - Test loss: 0.05158
# Epoch 4903 - lr: 0.01000 - Train loss: 0.04315 - Test loss: 0.05158
# Epoch 4904 - lr: 0.01000 - Train loss: 0.04315 - Test loss: 0.05158
# Epoch 4905 - lr: 0.01000 - Train loss: 0.04314 - Test loss: 0.05158
# Epoch 4906 - lr: 0.01000 - Train loss: 0.04314 - Test loss: 0.05158
# Epoch 4907 - lr: 0.01000 - Train loss: 0.04314 - Test loss: 0.05158
# Epoch 4908 - lr: 0.01000 - Train loss: 0.04314 - Test loss: 0.05158
# Epoch 4909 - lr: 0.01000 - Train loss: 0.04313 - Test loss: 0.05158
# Epoch 4910 - lr: 0.01000 - Train loss: 0.04313 - Test loss: 0.05158
# Epoch 4911 - lr: 0.01000 - Train loss: 0.04313 - Test loss: 0.05158
# Epoch 4912 - lr: 0.01000 - Train loss: 0.04312 - Test loss: 0.05158
# Epoch 4913 - lr: 0.01000 - Train loss: 0.04312 - Test loss: 0.05158
# Epoch 4914 - lr: 0.01000 - Train loss: 0.04312 - Test loss: 0.05158
# Epoch 4915 - lr: 0.01000 - Train loss: 0.04312 - Test loss: 0.05158
# Epoch 4916 - lr: 0.01000 - Train loss: 0.04311 - Test loss: 0.05158
# Epoch 4917 - lr: 0.01000 - Train loss: 0.04311 - Test loss: 0.05158
# Epoch 4918 - lr: 0.01000 - Train loss: 0.04311 - Test loss: 0.05158
# Epoch 4919 - lr: 0.01000 - Train loss: 0.04310 - Test loss: 0.05158
# Epoch 4920 - lr: 0.01000 - Train loss: 0.04310 - Test loss: 0.05158
# Epoch 4921 - lr: 0.01000 - Train loss: 0.04310 - Test loss: 0.05158
# Epoch 4922 - lr: 0.01000 - Train loss: 0.04310 - Test loss: 0.05158
# Epoch 4923 - lr: 0.01000 - Train loss: 0.04309 - Test loss: 0.05158
# Epoch 4924 - lr: 0.01000 - Train loss: 0.04309 - Test loss: 0.05158
# Epoch 4925 - lr: 0.01000 - Train loss: 0.04309 - Test loss: 0.05158
# Epoch 4926 - lr: 0.01000 - Train loss: 0.04308 - Test loss: 0.05158
# Epoch 4927 - lr: 0.01000 - Train loss: 0.04308 - Test loss: 0.05158
# Epoch 4928 - lr: 0.01000 - Train loss: 0.04308 - Test loss: 0.05158
# Epoch 4929 - lr: 0.01000 - Train loss: 0.04308 - Test loss: 0.05158
# Epoch 4930 - lr: 0.01000 - Train loss: 0.04307 - Test loss: 0.05158
# Epoch 4931 - lr: 0.01000 - Train loss: 0.04307 - Test loss: 0.05158
# Epoch 4932 - lr: 0.01000 - Train loss: 0.04307 - Test loss: 0.05158
# Epoch 4933 - lr: 0.01000 - Train loss: 0.04306 - Test loss: 0.05158
# Epoch 4934 - lr: 0.01000 - Train loss: 0.04306 - Test loss: 0.05158
# Epoch 4935 - lr: 0.01000 - Train loss: 0.04306 - Test loss: 0.05158
# Epoch 4936 - lr: 0.01000 - Train loss: 0.04306 - Test loss: 0.05158
# Epoch 4937 - lr: 0.01000 - Train loss: 0.04305 - Test loss: 0.05158
# Epoch 4938 - lr: 0.01000 - Train loss: 0.04305 - Test loss: 0.05158
# Epoch 4939 - lr: 0.01000 - Train loss: 0.04305 - Test loss: 0.05158
# Epoch 4940 - lr: 0.01000 - Train loss: 0.04304 - Test loss: 0.05158
# Epoch 4941 - lr: 0.01000 - Train loss: 0.04304 - Test loss: 0.05158
# Epoch 4942 - lr: 0.01000 - Train loss: 0.04304 - Test loss: 0.05158
# Epoch 4943 - lr: 0.01000 - Train loss: 0.04304 - Test loss: 0.05158
# Epoch 4944 - lr: 0.01000 - Train loss: 0.04303 - Test loss: 0.05158
# Epoch 4945 - lr: 0.01000 - Train loss: 0.04303 - Test loss: 0.05158
# Epoch 4946 - lr: 0.01000 - Train loss: 0.04303 - Test loss: 0.05158
# Epoch 4947 - lr: 0.01000 - Train loss: 0.04302 - Test loss: 0.05158
# Epoch 4948 - lr: 0.01000 - Train loss: 0.04302 - Test loss: 0.05158
# Epoch 4949 - lr: 0.01000 - Train loss: 0.04302 - Test loss: 0.05158
# Epoch 4950 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05158
# Epoch 4951 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05159
# Epoch 4952 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05159
# Epoch 4953 - lr: 0.01000 - Train loss: 0.04301 - Test loss: 0.05159
# Epoch 4954 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05159
# Epoch 4955 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05159
# Epoch 4956 - lr: 0.01000 - Train loss: 0.04300 - Test loss: 0.05159
# Epoch 4957 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05159
# Epoch 4958 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05159
# Epoch 4959 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05159
# Epoch 4960 - lr: 0.01000 - Train loss: 0.04299 - Test loss: 0.05159
# Epoch 4961 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05159
# Epoch 4962 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05159
# Epoch 4963 - lr: 0.01000 - Train loss: 0.04298 - Test loss: 0.05159
# Epoch 4964 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05159
# Epoch 4965 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05159
# Epoch 4966 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05159
# Epoch 4967 - lr: 0.01000 - Train loss: 0.04297 - Test loss: 0.05159
# Epoch 4968 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05159
# Epoch 4969 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05159
# Epoch 4970 - lr: 0.01000 - Train loss: 0.04296 - Test loss: 0.05159
# Epoch 4971 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05159
# Epoch 4972 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05159
# Epoch 4973 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05159
# Epoch 4974 - lr: 0.01000 - Train loss: 0.04295 - Test loss: 0.05159
# Epoch 4975 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05159
# Epoch 4976 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05159
# Epoch 4977 - lr: 0.01000 - Train loss: 0.04294 - Test loss: 0.05159
# Epoch 4978 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05159
# Epoch 4979 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05159
# Epoch 4980 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05159
# Epoch 4981 - lr: 0.01000 - Train loss: 0.04293 - Test loss: 0.05159
# Epoch 4982 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05159
# Epoch 4983 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05159
# Epoch 4984 - lr: 0.01000 - Train loss: 0.04292 - Test loss: 0.05159
# Epoch 4985 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05159
# Epoch 4986 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05159
# Epoch 4987 - lr: 0.01000 - Train loss: 0.04291 - Test loss: 0.05159
# Epoch 4988 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05159
# Epoch 4989 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05159
# Epoch 4990 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05159
# Epoch 4991 - lr: 0.01000 - Train loss: 0.04290 - Test loss: 0.05159
# Epoch 4992 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05159
# Epoch 4993 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05159
# Epoch 4994 - lr: 0.01000 - Train loss: 0.04289 - Test loss: 0.05159
# Epoch 4995 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05159
# Epoch 4996 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05159
# Epoch 4997 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05159
# Epoch 4998 - lr: 0.01000 - Train loss: 0.04288 - Test loss: 0.05159
# Epoch 4999 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05159
# Epoch 5000 - lr: 0.01000 - Train loss: 0.04287 - Test loss: 0.05159

# %% [markdown]
# Plot train and test loss during training

# %%
plt.close('all')
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(test_loss_log, label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot weights after training

# %%
net.plot_weights()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
### FORWARD PASS (after training)
net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, net_output, color='g', ls='--', label='Network output (trained weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Now the output is better, but it can still be improved by a large margin. Try to improve it by changing the network structure and the training hyper-parameters, but remember: **THIS MUST BE DONE ON A VALIDATION SET!**

# %% [markdown]
# # Analyze activations

# %% [markdown]
# By enabling the *additional_out* parameter of the *forward* method, we can see the activations of the last layer for a given input. Let's try with 3 different input values: $x=0.1$, $x=0.9$ and $x=2.5$.

# %%
x1 = 0.1
y1, z1 = net.forward(x1, additional_out=True)
x2 = 0.9
y2, z2 = net.forward(x2, additional_out=True)
x3 = 2.5
y3, z3 = net.forward(x3, additional_out=True)

fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1, use_line_collection=True)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2, use_line_collection=True)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3, use_line_collection=True)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# As you may have noticed, some neurons are contributing much more than the others. Maybe the number of neurons is too high? Try to make some changes and see what happens.
#
# In the last case the input is $x=2.5$, far away from the training space $[0,1]$. The behavior of the network seems to be quite confused, maybe it is not generalizing very well, try to do some tests to check this hypothesis.
